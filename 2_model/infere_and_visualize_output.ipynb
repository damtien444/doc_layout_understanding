# %%
from transformers import LayoutXLMProcessor, LayoutLMv2ForTokenClassification
from data_loader_coco_image import DocumentLayoutAnalysisDataset, unnormalize_bbox, color_map
import torch
import os

# os.environ['CUDA_VISIBLE_DEVICES']='1'

processor = LayoutXLMProcessor.from_pretrained(
    "microsoft/layoutxlm-base",
    apply_ocr=False,
    only_label_first_subword=False,
    is_split_into_words=True)

anno_file = "/home/tiendq/PycharmProjects/DeepLearningDocReconstruction/0_data_repository/1000DataForOCR_fineLabel_dataset_coco_v1.1_titleNsuptitle.json"
image_root_folder = "/home/tiendq/Desktop/DocRec/2_data_preparation/2_selected_sample"
torch_dataset = DocumentLayoutAnalysisDataset(image_root_folder, anno_file)

# model = LayoutLMv2ForTokenClassification.from_pretrained(
#     '/home/tiendq/Desktop/DocRec/3_model_checkpoint/GPU-4_0_model_repository/1_update_titleandsupertitle',
#     num_labels=len(torch_dataset.label_list),
#     id2label=torch_dataset.id2label,
#     label2id=torch_dataset.label2id)
# Out:
# /home/tiendq/anaconda3/envs/DeepLearningDocReconstruction/lib/python3.8/site-packages/transformers/models/layoutlmv2/feature_extraction_layoutlmv2.py:30: FutureWarning: The class LayoutLMv2FeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use LayoutLMv2ImageProcessor instead.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.34s)
# creating index...
# index created!

# %%
from PIL import Image

image_column_name = "image"
text_column_name = "words"
boxes_column_name = "boxes"
label_column_name = "labels_id"

examples = torch_dataset[300]

images = Image.open(examples['image_path']).convert("RGB")
words = examples[text_column_name]
boxes = examples[boxes_column_name]
word_labels = examples[label_column_name]

# %%
encoding = processor(images, words, boxes=boxes, word_labels=word_labels, truncation=True, stride =128,
         padding="max_length", max_length=512, return_overflowing_tokens=True, return_offsets_mapping=True, return_tensors='pt')

offset_mapping = encoding.pop('offset_mapping')

overflow_to_sample_mapping = encoding.pop('overflow_to_sample_mapping')

# %%
encoding['labels'].shape
# Out:
# torch.Size([2, 512])

# %%
tokens = processor.tokenizer.convert_ids_to_tokens(encoding["input_ids"][0])

# Create .txt file
with open("test.txt", "w") as f:
    f.write(" ".join(tokens))

# Create .ann file
with open("test.ann", "w") as f:
    entity_id = 1
    for i, label in enumerate(word_labels):
        if label:
            start_offset = encoding["offset_mapping"][0][i][0]
            end_offset = encoding["offset_mapping"][0][i][1]
            entity_text = " ".join(tokens[i].split("##")) # Account for sub-word tokens
            f.write(f"T{entity_id}\t{label} {start_offset} {end_offset}\t{entity_text}\n")
            entity_id += 1

# %%
encoding['labels']
# Out:
# tensor([[-100,    8,    8,  ...,    8,    8, -100],
#         [-100,    2,    2,  ..., -100, -100, -100]])

# %%
token_boxes = encoding.bbox.squeeze().tolist()

# %%
for i in range(0, len(token_boxes)):
    for j in range(0, len(token_boxes[i])):
        if token_boxes[i][j] == [0,0,0,0] or token_boxes[i][j] == [1000,1000,1000,1000]:
            continue

        print("provided label is: {}, bbox is: {} and the text is: {}".format(torch_dataset.id2label[int(encoding['labels'][i][j])], token_boxes[i][j],  processor.tokenizer.decode(encoding["input_ids"][i][j])))

        print(f'FULL BOX text is: {words[encoding.token_to_word(i,j)]}')
# Out:
# provided label is: starting, bbox is: [183, 118, 377, 140] and the text is: (
# FULL BOX text is: (Đề thi có 05 trang)
# provided label is: starting, bbox is: [183, 118, 377, 140] and the text is: Đ
# FULL BOX text is: (Đề thi có 05 trang)
# provided label is: starting, bbox is: [183, 118, 377, 140] and the text is: ề
# FULL BOX text is: (Đề thi có 05 trang)
# provided label is: starting, bbox is: [183, 118, 377, 140] and the text is: thi
# FULL BOX text is: (Đề thi có 05 trang)
# provided label is: starting, bbox is: [183, 118, 377, 140] and the text is: có
# FULL BOX text is: (Đề thi có 05 trang)
# provided label is: starting, bbox is: [183, 118, 377, 140] and the text is: 05
# FULL BOX text is: (Đề thi có 05 trang)
# provided label is: starting, bbox is: [183, 118, 377, 140] and the text is: trang
# FULL BOX text is: (Đề thi có 05 trang)
# provided label is: starting, bbox is: [183, 118, 377, 140] and the text is: )
# FULL BOX text is: (Đề thi có 05 trang)
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: D
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: .
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: Phân
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: chia
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: phạm
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: vi
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: ảnh
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: hưởng
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: ở
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: châu
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: Âu
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: ,
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: châu
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: Á
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: answer, bbox is: [159, 344, 659, 365] and the text is: .
# FULL BOX text is: D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: Thời
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: gian
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: làm
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: bài
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: :
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: 50
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: phút
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: ,
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: không
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: kể
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: thời
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [485, 118, 931, 140] and the text is: gian
# FULL BOX text is: Thời gian làm bài: 50 phút, không kể thời gian
# provided label is: starting, bbox is: [669, 138, 748, 159] and the text is: phát
# FULL BOX text is: phát để
# provided label is: starting, bbox is: [669, 138, 748, 159] and the text is: để
# FULL BOX text is: phát để
# provided label is: starting, bbox is: [630, 180, 774, 198] and the text is: Mã
# FULL BOX text is: Mã đề thi (01
# provided label is: starting, bbox is: [630, 180, 774, 198] and the text is: đề
# FULL BOX text is: Mã đề thi (01
# provided label is: starting, bbox is: [630, 180, 774, 198] and the text is: thi
# FULL BOX text is: Mã đề thi (01
# provided label is: starting, bbox is: [630, 180, 774, 198] and the text is: (
# FULL BOX text is: Mã đề thi (01
# provided label is: starting, bbox is: [630, 180, 774, 198] and the text is: 01
# FULL BOX text is: Mã đề thi (01
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: Họ
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: và
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: tên
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: thí
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: sinh
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: :
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: .......
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: ................
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: ................
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: ................
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [114, 219, 730, 239] and the text is: ................
# FULL BOX text is: Họ và tên thí sinh: .......................................................................
# provided label is: starting, bbox is: [251, 78, 310, 98] and the text is: T
# FULL BOX text is: TẠO
# provided label is: starting, bbox is: [251, 78, 310, 98] and the text is: Ạ
# FULL BOX text is: TẠO
# provided label is: starting, bbox is: [251, 78, 310, 98] and the text is: O
# FULL BOX text is: TẠO
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: Câu
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: 2.
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: Ngày
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: 24
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: -10-
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: 1945
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: ,
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: sau
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: khi
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: Quốc
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: hội
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: các
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: nước
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: thành
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: viên
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: phê
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: chuẩn
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: ,
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: bản
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: Hi
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [113, 365, 926, 386] and the text is: ến
# FULL BOX text is: Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến
# provided label is: title, bbox is: [115, 387, 373, 408] and the text is: chương
# FULL BOX text is: chương của Liên hợp quốc
# provided label is: title, bbox is: [115, 387, 373, 408] and the text is: của
# FULL BOX text is: chương của Liên hợp quốc
# provided label is: title, bbox is: [115, 387, 373, 408] and the text is: Liên
# FULL BOX text is: chương của Liên hợp quốc
# provided label is: title, bbox is: [115, 387, 373, 408] and the text is: hợp
# FULL BOX text is: chương của Liên hợp quốc
# provided label is: title, bbox is: [115, 387, 373, 408] and the text is: quốc
# FULL BOX text is: chương của Liên hợp quốc
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: A
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: .
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: được
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: bổ
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: sung
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: ,
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: hoàn
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: chỉnh
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [160, 407, 443, 428] and the text is: .
# FULL BOX text is: A. được bổ sung, hoàn chỉnh.
# provided label is: answer, bbox is: [159, 428, 408, 449] and the text is: C
# FULL BOX text is: C. chính thức có hiệu lực.
# provided label is: answer, bbox is: [159, 428, 408, 449] and the text is: .
# FULL BOX text is: C. chính thức có hiệu lực.
# provided label is: answer, bbox is: [159, 428, 408, 449] and the text is: chính
# FULL BOX text is: C. chính thức có hiệu lực.
# provided label is: answer, bbox is: [159, 428, 408, 449] and the text is: thức
# FULL BOX text is: C. chính thức có hiệu lực.
# provided label is: answer, bbox is: [159, 428, 408, 449] and the text is: có
# FULL BOX text is: C. chính thức có hiệu lực.
# provided label is: answer, bbox is: [159, 428, 408, 449] and the text is: hiệu
# FULL BOX text is: C. chính thức có hiệu lực.
# provided label is: answer, bbox is: [159, 428, 408, 449] and the text is: lực
# FULL BOX text is: C. chính thức có hiệu lực.
# provided label is: answer, bbox is: [159, 428, 408, 449] and the text is: .
# FULL BOX text is: C. chính thức có hiệu lực.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: C
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: ,
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: thực
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: hiện
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: Kế
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: hoạch
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: M
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: ács
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: an
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: ,
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: giúp
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: Tây
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: Âu
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: phục
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: hồi
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: kinh
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: tế
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [160, 645, 745, 666] and the text is: .
# FULL BOX text is: C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.
# provided label is: answer, bbox is: [537, 406, 810, 429] and the text is: È
# FULL BOX text is: È, chính thức được công bố.
# provided label is: answer, bbox is: [537, 406, 810, 429] and the text is: ,
# FULL BOX text is: È, chính thức được công bố.
# provided label is: answer, bbox is: [537, 406, 810, 429] and the text is: chính
# FULL BOX text is: È, chính thức được công bố.
# provided label is: answer, bbox is: [537, 406, 810, 429] and the text is: thức
# FULL BOX text is: È, chính thức được công bố.
# provided label is: answer, bbox is: [537, 406, 810, 429] and the text is: được
# FULL BOX text is: È, chính thức được công bố.
# provided label is: answer, bbox is: [537, 406, 810, 429] and the text is: công
# FULL BOX text is: È, chính thức được công bố.
# provided label is: answer, bbox is: [537, 406, 810, 429] and the text is: bố
# FULL BOX text is: È, chính thức được công bố.
# provided label is: answer, bbox is: [537, 406, 810, 429] and the text is: .
# FULL BOX text is: È, chính thức được công bố.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: D
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: .
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: viện
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: trợ
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: khẩn
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: cấp
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: 400
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: triệu
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: USD
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: cho
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: Hi
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: L
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: ạp
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: và
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: Th
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: ổ
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: Nh
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: ĩ
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: K
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: ì
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 666, 756, 687] and the text is: .
# FULL BOX text is: D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: D
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: .
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: thúc
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: đẩy
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: tốc
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: độ
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: tăng
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: trưởng
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: của
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: các
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: ngành
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: công
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: nghiệp
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: nhẹ
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: trong
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: nước
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [160, 794, 862, 814] and the text is: .
# FULL BOX text is: D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: Cầu
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: 5.
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: Sau
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: khi
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: giành
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: được
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: độc
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: lập
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: ,
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: nhóm
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: năm
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: nước
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: sáng
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: lập
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: ASEAN
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: thực
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: hiện
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: answer, bbox is: [114, 688, 932, 709] and the text is: chiến
# FULL BOX text is: Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: Câu
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: 6.
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: Ngoài
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: việc
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: giúp
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: các
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: nước
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: Tây
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: Âu
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: phục
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: hồi
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: nền
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: kinh
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: tế
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: ,
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: Kế
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: hoạch
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: M
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: ács
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: an
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: title, bbox is: [114, 815, 926, 836] and the text is: của
# FULL BOX text is: Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: T
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: ược
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: kinh
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: tế
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: hướng
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: nội
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: với
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: mục
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [114, 710, 459, 731] and the text is: tiêu
# FULL BOX text is: Tược kinh tế hướng nội với mục tiêu
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: C
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: .
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: nhanh
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: chóng
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: vươn
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: lên
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: trở
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: thành
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: những
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: nước
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: công
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: nghiệp
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: mới
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: (
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: NIC
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: s
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 773, 849, 793] and the text is: ).
# FULL BOX text is: C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: À
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: .
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: khô
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: i
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: phục
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: sự
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: phát
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: triển
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: của
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: các
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: ngành
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: công
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: nghiệp
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: nặng
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: ở
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: các
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: nước
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 730, 833, 750] and the text is: .
# FULL BOX text is: À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: B
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: .
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: nhanh
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: chóng
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: xóa
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: bỏ
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: nghèo
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: n
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: àn
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: ,
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: lạc
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: hậu
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: ,
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: xây
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: dựng
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: nền
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: kinh
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: tế
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: tự
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: chủ
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [160, 751, 840, 771] and the text is: .
# FULL BOX text is: B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.
# provided label is: answer, bbox is: [537, 428, 830, 450] and the text is: D
# FULL BOX text is: D. được chính thức thông qua.
# provided label is: answer, bbox is: [537, 428, 830, 450] and the text is: .
# FULL BOX text is: D. được chính thức thông qua.
# provided label is: answer, bbox is: [537, 428, 830, 450] and the text is: được
# FULL BOX text is: D. được chính thức thông qua.
# provided label is: answer, bbox is: [537, 428, 830, 450] and the text is: chính
# FULL BOX text is: D. được chính thức thông qua.
# provided label is: answer, bbox is: [537, 428, 830, 450] and the text is: thức
# FULL BOX text is: D. được chính thức thông qua.
# provided label is: answer, bbox is: [537, 428, 830, 450] and the text is: thông
# FULL BOX text is: D. được chính thức thông qua.
# provided label is: answer, bbox is: [537, 428, 830, 450] and the text is: qua
# FULL BOX text is: D. được chính thức thông qua.
# provided label is: answer, bbox is: [537, 428, 830, 450] and the text is: .
# FULL BOX text is: D. được chính thức thông qua.
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: Câu
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: 3.
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: Những
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: năm
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: đầu
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: sau
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: khi
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: Liên
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: X
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: ô
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: tan
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is:
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: rã
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: ,
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: Diện
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: bang
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: Nga
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: thực
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: hiện
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: chính
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: title, bbox is: [113, 449, 909, 471] and the text is: sách
# FULL BOX text is: Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: D
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: .
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: tăng
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: cường
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: hợp
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: lắc
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: khoa
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: học
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: kĩ
# FULL BOX text is: D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.
# provided label is: answer, bbox is: [159, 559, 759, 579] and the text is: thuật
# ...
# provided label is: answer, bbox is: [159, 921, 725, 943] and the text is: xã
# FULL BOX text is: D. tổ chức chính trị-quân sự chống lại phe xã hội chủ nghĩa.
# provided label is: answer, bbox is: [159, 921, 725, 943] and the text is: hội
# FULL BOX text is: D. tổ chức chính trị-quân sự chống lại phe xã hội chủ nghĩa.
# provided label is: answer, bbox is: [159, 921, 725, 943] and the text is: chủ
# FULL BOX text is: D. tổ chức chính trị-quân sự chống lại phe xã hội chủ nghĩa.
# provided label is: answer, bbox is: [159, 921, 725, 943] and the text is: nghĩa
# FULL BOX text is: D. tổ chức chính trị-quân sự chống lại phe xã hội chủ nghĩa.
# provided label is: answer, bbox is: [159, 921, 725, 943] and the text is: .
# FULL BOX text is: D. tổ chức chính trị-quân sự chống lại phe xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: C
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: .
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: liên
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: minh
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: chính
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: trị
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: chống
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: Liên
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: X
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: ô
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: và
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: các
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: nước
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: Đông
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: Âu
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 900, 726, 921] and the text is: .
# FULL BOX text is: C. liên minh chính trị chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: B
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: .
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: liên
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: minh
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: quân
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: sự
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: chống
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: Liên
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: X
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: ô
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: và
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: các
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: nước
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: Đông
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: Âu
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 878, 720, 899] and the text is: .
# FULL BOX text is: B. liên minh quân sự chống Liên Xô và các nước Đông Âu.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: A
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: .
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: liên
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: minh
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: kinh
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: tế
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: đối
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: lập
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: với
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: các
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: nước
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: xã
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: hội
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: chủ
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: nghĩa
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: answer, bbox is: [160, 857, 714, 878] and the text is: .
# FULL BOX text is: A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: M
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: ĩ
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: (19
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: 47)
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: còn
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: nhằm
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: tập
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: hợp
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: các
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: nước
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: Tây
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: Âu
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: title, bbox is: [115, 838, 598, 859] and the text is: vào
# FULL BOX text is: Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: Đ
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: Ề
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is:
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: THI
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: TH
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: Ử
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: NG
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: HI
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: Ệ
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [160, 98, 400, 121] and the text is: M
# FULL BOX text is: ĐỀ THI THỬ NGHIỆM
# provided label is: starting, bbox is: [625, 78, 789, 95] and the text is:
# FULL BOX text is: GIA NĂM 2017
# provided label is: starting, bbox is: [625, 78, 789, 95] and the text is: GIA
# FULL BOX text is: GIA NĂM 2017
# provided label is: starting, bbox is: [625, 78, 789, 95] and the text is: N
# FULL BOX text is: GIA NĂM 2017
# provided label is: starting, bbox is: [625, 78, 789, 95] and the text is: Ă
# FULL BOX text is: GIA NĂM 2017
# provided label is: starting, bbox is: [625, 78, 789, 95] and the text is: M
# FULL BOX text is: GIA NĂM 2017
# provided label is: starting, bbox is: [625, 78, 789, 95] and the text is: 2017
# FULL BOX text is: GIA NĂM 2017
# provided label is: header, bbox is: [75, 0, 266, 19] and the text is: VI
# FULL BOX text is: VIET,JACK.COM
# provided label is: header, bbox is: [75, 0, 266, 19] and the text is: ET
# FULL BOX text is: VIET,JACK.COM
# provided label is: header, bbox is: [75, 0, 266, 19] and the text is: ,
# FULL BOX text is: VIET,JACK.COM
# provided label is: header, bbox is: [75, 0, 266, 19] and the text is: JA
# FULL BOX text is: VIET,JACK.COM
# provided label is: header, bbox is: [75, 0, 266, 19] and the text is: CK
# FULL BOX text is: VIET,JACK.COM
# provided label is: header, bbox is: [75, 0, 266, 19] and the text is: .
# FULL BOX text is: VIET,JACK.COM
# provided label is: header, bbox is: [75, 0, 266, 19] and the text is: COM
# FULL BOX text is: VIET,JACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: Học
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: trực
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: tuyến
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: :
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: KH
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: OA
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: HỌC
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: .
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: VIE
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: T
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: JA
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: CK
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: .
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: header, bbox is: [342, 0, 835, 20] and the text is: COM
# FULL BOX text is: Học trực tuyến: KHOA HỌC.VIETJACK.COM
# provided label is: footer, bbox is: [74, 949, 378, 969] and the text is: Facebook
# FULL BOX text is: Facebook: Học cùng Vietjack
# provided label is: footer, bbox is: [74, 949, 378, 969] and the text is: :
# FULL BOX text is: Facebook: Học cùng Vietjack
# provided label is: footer, bbox is: [74, 949, 378, 969] and the text is: Học
# FULL BOX text is: Facebook: Học cùng Vietjack
# provided label is: footer, bbox is: [74, 949, 378, 969] and the text is: cùng
# FULL BOX text is: Facebook: Học cùng Vietjack
# provided label is: footer, bbox is: [74, 949, 378, 969] and the text is: Viet
# FULL BOX text is: Facebook: Học cùng Vietjack
# provided label is: footer, bbox is: [74, 949, 378, 969] and the text is: jack
# FULL BOX text is: Facebook: Học cùng Vietjack
# provided label is: footer, bbox is: [518, 949, 805, 970] and the text is: Youtube
# FULL BOX text is: Youtube:Học cùng Vietjack
# provided label is: footer, bbox is: [518, 949, 805, 970] and the text is: :
# FULL BOX text is: Youtube:Học cùng Vietjack
# provided label is: footer, bbox is: [518, 949, 805, 970] and the text is: H
# FULL BOX text is: Youtube:Học cùng Vietjack
# provided label is: footer, bbox is: [518, 949, 805, 970] and the text is: ọc
# FULL BOX text is: Youtube:Học cùng Vietjack
# provided label is: footer, bbox is: [518, 949, 805, 970] and the text is: cùng
# FULL BOX text is: Youtube:Học cùng Vietjack
# provided label is: footer, bbox is: [518, 949, 805, 970] and the text is: Viet
# FULL BOX text is: Youtube:Học cùng Vietjack
# provided label is: footer, bbox is: [518, 949, 805, 970] and the text is: jack
# FULL BOX text is: Youtube:Học cùng Vietjack

# %%
del encoding['labels']

# %%
# import numpy as np
x = []
for i in range(0, len(encoding['image'])):
     x.append(encoding['image'][i])
x = torch.stack(x)
encoding['image'] = x

# %%
for k,v in encoding.items():
  print(k,type(v), v.shape, sep="\t\t\t\t")
# Out:
# input_ids				<class 'torch.Tensor'>				torch.Size([2, 512])
# attention_mask				<class 'torch.Tensor'>				torch.Size([2, 512])
# bbox				<class 'torch.Tensor'>				torch.Size([2, 512, 4])
# image				<class 'torch.Tensor'>				torch.Size([2, 3, 224, 224])

# %%
with torch.no_grad():
  outputs = model(**encoding)

# The model outputs logits of shape (batch_size, seq_len, num_labels).
logits = outputs.logits
print(logits.shape)

# We take the highest score for each token, using argmax. This serves as the predicted label for each token.
predictions = logits.argmax(-1).squeeze().tolist()
token_boxes = encoding.bbox.squeeze().tolist()
# original_words = encoding.word_ids()
if (len(token_boxes) == 512):
  predictions = [predictions]
  token_boxes = [token_boxes]
# Out:
# torch.Size([2, 512, 9])

# %%
# Out:
# TokenClassifierOutput(loss=None, logits=tensor([[[-1.3280, -1.9619, -0.7244,  ..., -1.3870, -1.5125, 11.2898],
#          [-1.3148, -1.9169, -0.7642,  ..., -1.3464, -1.4291, 11.3161],
#          [-1.3102, -1.7967, -0.4242,  ..., -1.4428, -1.6221, 10.9942],
#          ...,
#          [-1.0703, -1.6430, -1.1171,  ..., -0.8316, -1.7563, 11.3303],
#          [-1.0469, -1.6576, -1.1222,  ..., -0.8664, -1.6909, 11.4204],
#          [ 1.8050, -2.9063,  4.9642,  ..., -1.9465, -2.1395,  4.7034]],
#
#         [[-1.6905, -2.0083, 11.1895,  ..., -1.7055, -1.8943, -1.7163],
#          [-1.4106, -1.9546, 11.3582,  ..., -1.8947, -2.1416, -1.8549],
#          [-1.6100, -1.9521, 11.1932,  ..., -1.8369, -2.0665, -1.6602],
#          ...,
#          [-1.3872, -0.4273, -1.5600,  ..., -1.3751, -1.0653, -0.7592],
#          [-1.3995, -0.5256, -1.6096,  ..., -1.3290, -1.0919, -0.7561],
#          [-1.3771, -0.4597, -1.5576,  ..., -1.3910, -1.0577, -0.7153]]]), hidden_states=None, attentions=None)

# %%
words[0]
# Out:
# '(Đề thi có 05 trang)'

# %%
len(token_boxes), token_boxes[0]
# Out:
# (2,
#  [[0, 0, 0, 0],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [669, 138, 748, 159],
#   [669, 138, 748, 159],
#   [630, 180, 774, 198],
#   [630, 180, 774, 198],
#   [630, 180, 774, 198],
#   [630, 180, 774, 198],
#   [630, 180, 774, 198],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [251, 78, 310, 98],
#   [251, 78, 310, 98],
#   [251, 78, 310, 98],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [115, 387, 373, 408],
#   [115, 387, 373, 408],
#   [115, 387, 373, 408],
#   [115, 387, 373, 408],
#   [115, 387, 373, 408],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [537, 406, 810, 429],
#   [537, 406, 810, 429],
#   [537, 406, 810, 429],
#   [537, 406, 810, 429],
#   [537, 406, 810, 429],
#   [537, 406, 810, 429],
#   [537, 406, 810, 429],
#   [537, 406, 810, 429],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 815, 926, 836],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 730, 833, 750],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [160, 624, 736, 644],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [159, 537, 738, 558],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [160, 494, 609, 515],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [115, 238, 251, 258],
#   [115, 238, 251, 258],
#   [115, 238, 251, 258],
#   [115, 238, 251, 258],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 257, 794, 278],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [1000, 1000, 1000, 1000]])

# %%
for i in range(0, len(token_boxes)):
    for j in range(0, len(token_boxes[i])):
        if token_boxes[i][j] == [0,0,0,0] or token_boxes[i][j] == [1000,1000,1000,1000]:
            continue
        print("prediction label is: {}, bbox is: {} and the text is: {}".format(torch_dataset.id2label[predictions[i][j]], token_boxes[i][j],  processor.tokenizer.decode(encoding["input_ids"][i][j])))

        print(f'original text is: {words[encoding.token_to_word(i,j)]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       3 if token_boxes[i][j] == [0,0,0,0] or token_boxes[i][j] == [1000,1000,1000,1000]:
#       4     continue
# ----> 5 print("label is: {}, bbox is: {} and the text is: {}".format(torch_dataset.id2label[predictions[i][j]], token_boxes[i][j],  processor.tokenizer.decode(encoding["input_ids"][i][j])))
#       7 print(f'original text is: {words[encoding.token_to_word(i,j)]}')
#
# NameError: name 'predictions' is not defined

# %%
instance_dict = {}

# iterate batch sample
for i in range(0, len(token_boxes)):
    # iterate token in batch
    for j in range(0, len(token_boxes[i])):
        box = tuple(token_boxes[i][j])
        if box == (0,0,0,0) or box == (1000,1000,1000,1000):
            continue
        if box not in instance_dict:
            instance_dict[box] = {"token_list":[(processor.decode(encoding["input_ids"][i][j]),predictions[i][j])],
                                  "original_string": words[encoding.token_to_word(i,j)]}
        else:
            instance_dict[box]['token_list'].append((processor.decode(encoding["input_ids"][i][j]),predictions[i][j]))

# %%
instance_dict
# Out:
# {(183,
#   118,
#   377,
#   140): {'token_list': [('(', 8),
#    ('Đ', 8),
#    ('ề', 8),
#    ('thi', 8),
#    ('có', 8),
#    ('05', 8),
#    ('trang', 8),
#    (')', 8)], 'original_string': '(Đề thi có 05 trang)'},
#  (159,
#   344,
#   659,
#   365): {'token_list': [('D', 2),
#    ('.', 2),
#    ('Phân', 2),
#    ('chia', 2),
#    ('phạm', 2),
#    ('vi', 2),
#    ('ảnh', 2),
#    ('hưởng', 2),
#    ('ở', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    (',', 2),
#    ('châu', 2),
#    ('Á', 2),
#    ('.',
#     2)], 'original_string': 'D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.'},
#  (485,
#   118,
#   931,
#   140): {'token_list': [('Thời', 8),
#    ('gian', 8),
#    ('làm', 8),
#    ('bài', 8),
#    (':', 8),
#    ('50', 8),
#    ('phút', 8),
#    (',', 8),
#    ('không', 8),
#    ('kể', 8),
#    ('thời', 8),
#    ('gian',
#     8)], 'original_string': 'Thời gian làm bài: 50 phút, không kể thời gian'},
#  (669, 138, 748, 159): {'token_list': [('phát', 8), ('để', 8)],
#   'original_string': 'phát để'},
#  (630,
#   180,
#   774,
#   198): {'token_list': [('Mã', 8),
#    ('đề', 8),
#    ('thi', 8),
#    ('(', 8),
#    ('01', 8)], 'original_string': 'Mã đề thi (01'},
#  (114,
#   219,
#   730,
#   239): {'token_list': [('Họ', 8),
#    ('và', 8),
#    ('tên', 8),
#    ('thí', 8),
#    ('sinh', 8),
#    (':', 8),
#    ('.......', 8),
#    ('................', 8),
#    ('................', 8),
#    ('................', 8),
#    ('................',
#     8)], 'original_string': 'Họ và tên thí sinh: .......................................................................'},
#  (251, 78, 310, 98): {'token_list': [('T', 8), ('Ạ', 8), ('O', 8)],
#   'original_string': 'TẠO'},
#  (113,
#   365,
#   926,
#   386): {'token_list': [('Câu', 0),
#    ('2.', 0),
#    ('Ngày', 0),
#    ('24', 0),
#    ('-10-', 0),
#    ('1945', 0),
#    (',', 0),
#    ('sau', 0),
#    ('khi', 0),
#    ('Quốc', 0),
#    ('hội', 0),
#    ('các', 0),
#    ('nước', 0),
#    ('thành', 0),
#    ('viên', 0),
#    ('phê', 0),
#    ('chuẩn', 0),
#    (',', 0),
#    ('bản', 0),
#    ('Hi', 0),
#    ('ến',
#     0)], 'original_string': 'Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến'},
#  (115,
#   387,
#   373,
#   408): {'token_list': [('chương', 0),
#    ('của', 0),
#    ('Liên', 0),
#    ('hợp', 0),
#    ('quốc', 0)], 'original_string': 'chương của Liên hợp quốc'},
#  (160,
#   407,
#   443,
#   428): {'token_list': [('A', 2),
#    ('.', 2),
#    ('được', 2),
#    ('bổ', 2),
#    ('sung', 2),
#    (',', 2),
#    ('hoàn', 2),
#    ('chỉnh', 2),
#    ('.', 2)], 'original_string': 'A. được bổ sung, hoàn chỉnh.'},
#  (159,
#   428,
#   408,
#   449): {'token_list': [('C', 2),
#    ('.', 2),
#    ('chính', 2),
#    ('thức', 2),
#    ('có', 2),
#    ('hiệu', 2),
#    ('lực', 2),
#    ('.', 2)], 'original_string': 'C. chính thức có hiệu lực.'},
#  (160,
#   645,
#   745,
#   666): {'token_list': [('C', 2),
#    (',', 2),
#    ('thực', 2),
#    ('hiện', 2),
#    ('Kế', 2),
#    ('hoạch', 2),
#    ('M', 2),
#    ('ács', 2),
#    ('an', 2),
#    (',', 2),
#    ('giúp', 2),
#    ('Tây', 2),
#    ('Âu', 2),
#    ('phục', 2),
#    ('hồi', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('.',
#     2)], 'original_string': 'C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.'},
#  (537,
#   406,
#   810,
#   429): {'token_list': [('È', 2),
#    (',', 2),
#    ('chính', 2),
#    ('thức', 2),
#    ('được', 2),
#    ('công', 2),
#    ('bố', 2),
#    ('.', 2)], 'original_string': 'È, chính thức được công bố.'},
#  (160,
#   666,
#   756,
#   687): {'token_list': [('D', 2),
#    ('.', 2),
#    ('viện', 2),
#    ('trợ', 2),
#    ('khẩn', 2),
#    ('cấp', 2),
#    ('400', 2),
#    ('triệu', 2),
#    ('USD', 2),
#    ('cho', 2),
#    ('Hi', 2),
#    ('L', 2),
#    ('ạp', 2),
#    ('và', 2),
#    ('Th', 2),
#    ('ổ', 2),
#    ('Nh', 2),
#    ('ĩ', 2),
#    ('K', 2),
#    ('ì', 2),
#    ('.',
#     2)], 'original_string': 'D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.'},
#  (160,
#   794,
#   862,
#   814): {'token_list': [('D', 2),
#    ('.', 2),
#    ('thúc', 2),
#    ('đẩy', 2),
#    ('tốc', 2),
#    ('độ', 2),
#    ('tăng', 2),
#    ('trưởng', 2),
#    ('của', 2),
#    ('các', 2),
#    ('ngành', 2),
#    ('công', 2),
#    ('nghiệp', 2),
#    ('nhẹ', 2),
#    ('trong', 2),
#    ('nước', 2),
#    ('.',
#     2)], 'original_string': 'D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.'},
#  (114,
#   688,
#   932,
#   709): {'token_list': [('Cầu', 2),
#    ('5.', 2),
#    ('Sau', 2),
#    ('khi', 2),
#    ('giành', 2),
#    ('được', 2),
#    ('độc', 2),
#    ('lập', 2),
#    (',', 2),
#    ('nhóm', 2),
#    ('năm', 2),
#    ('nước', 2),
#    ('sáng', 2),
#    ('lập', 2),
#    ('ASEAN', 2),
#    ('thực', 2),
#    ('hiện', 2),
#    ('chiến',
#     2)], 'original_string': 'Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến'},
#  (114,
#   815,
#   926,
#   836): {'token_list': [('Câu', 0),
#    ('6.', 0),
#    ('Ngoài', 0),
#    ('việc', 0),
#    ('giúp', 0),
#    ('các', 0),
#    ('nước', 0),
#    ('Tây', 0),
#    ('Âu', 0),
#    ('phục', 0),
#    ('hồi', 0),
#    ('nền', 0),
#    ('kinh', 0),
#    ('tế', 0),
#    (',', 0),
#    ('Kế', 0),
#    ('hoạch', 0),
#    ('M', 0),
#    ('ács', 0),
#    ('an', 0),
#    ('của',
#     0)], 'original_string': 'Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của'},
#  (114,
#   710,
#   459,
#   731): {'token_list': [('T', 2),
#    ('ược', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('hướng', 2),
#    ('nội', 2),
#    ('với', 2),
#    ('mục', 2),
#    ('tiêu', 2)], 'original_string': 'Tược kinh tế hướng nội với mục tiêu'},
#  (160,
#   773,
#   849,
#   793): {'token_list': [('C', 2),
#    ('.', 2),
#    ('nhanh', 2),
#    ('chóng', 2),
#    ('vươn', 2),
#    ('lên', 2),
#    ('trở', 2),
#    ('thành', 2),
#    ('những', 2),
#    ('nước', 2),
#    ('công', 2),
#    ('nghiệp', 2),
#    ('mới', 2),
#    ('(', 2),
#    ('NIC', 2),
#    ('s', 2),
#    (').',
#     2)], 'original_string': 'C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).'},
#  (160,
#   730,
#   833,
#   750): {'token_list': [('À', 2),
#    ('.', 2),
#    ('khô', 2),
#    ('i', 2),
#    ('phục', 2),
#    ('sự', 2),
#    ('phát', 2),
#    ('triển', 2),
#    ('của', 2),
#    ('các', 2),
#    ('ngành', 2),
#    ('công', 2),
#    ('nghiệp', 2),
#    ('nặng', 2),
#    ('ở', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('.',
#     2)], 'original_string': 'À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.'},
#  (160,
#   751,
#   840,
#   771): {'token_list': [('B', 2),
#    ('.', 2),
#    ('nhanh', 2),
#    ('chóng', 2),
#    ('xóa', 2),
#    ('bỏ', 2),
#    ('nghèo', 2),
#    ('n', 2),
#    ('àn', 2),
#    (',', 2),
#    ('lạc', 2),
#    ('hậu', 2),
#    (',', 2),
#    ('xây', 2),
#    ('dựng', 2),
#    ('nền', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('tự', 2),
#    ('chủ', 2),
#    ('.',
#     2)], 'original_string': 'B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.'},
#  (537,
#   428,
#   830,
#   450): {'token_list': [('D', 2),
#    ('.', 2),
#    ('được', 2),
#    ('chính', 2),
#    ('thức', 2),
#    ('thông', 2),
#    ('qua', 2),
#    ('.', 2)], 'original_string': 'D. được chính thức thông qua.'},
#  (113,
#   449,
#   909,
#   471): {'token_list': [('Câu', 0),
#    ('3.', 0),
#    ('Những', 0),
#    ('năm', 0),
#    ('đầu', 0),
#    ('sau', 0),
#    ('khi', 0),
#    ('Liên', 0),
#    ('X', 0),
#    ('ô', 0),
#    ('tan', 0),
#    ('', 0),
#    ('rã', 0),
#    (',', 0),
#    ('Diện', 0),
#    ('bang', 0),
#    ('Nga', 0),
#    ('thực', 0),
#    ('hiện', 0),
#    ('chính', 0),
#    ('sách',
#     0)], 'original_string': 'Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách'},
#  (159,
#   559,
#   759,
#   579): {'token_list': [('D', 2),
#    ('.', 2),
#    ('tăng', 2),
#    ('cường', 2),
#    ('hợp', 2),
#    ('lắc', 2),
#    ('khoa', 2),
#    ('học', 2),
#    ('kĩ', 2),
#    ('thuật', 2),
#    ('với', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    ('.',
#     2)], 'original_string': 'D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.'},
#  (115,
#   580,
#   745,
#   601): {'token_list': [('Câu', 0),
#    ('4.', 0),
#    ('Tại', 0),
#    ('Quốc', 0),
#    ('hội', 0),
#    ('M', 0),
#    ('ĩ', 0),
#    ('(12', 0),
#    ('-3', 0),
#    ('-', 0),
#    ('1947', 0),
#    ('),', 0),
#    ('Tổng', 0),
#    ('thống', 0),
#    ('Tru', 0),
#    ('man', 0),
#    ('đề', 0),
#    ('nghị',
#     0)], 'original_string': 'Câu 4. Tại Quốc hội Mĩ (12-3-1947), Tổng thống Truman đề nghị'},
#  (160,
#   602,
#   741,
#   622): {'token_list': [('A', 2),
#    ('.', 2),
#    ('thành', 2),
#    ('lập', 2),
#    ('Tổ', 2),
#    ('chức', 2),
#    ('Hiệp', 2),
#    ('ước', 2),
#    ('Bắc', 2),
#    ('Đại', 2),
#    ('Tây', 2),
#    ('Dương', 2),
#    ('(', 2),
#    ('NATO', 2),
#    (').',
#     2)], 'original_string': 'A. thành lập Tổ chức Hiệp ước Bắc Đại Tây Dương (NATO).'},
#  (160,
#   624,
#   736,
#   644): {'token_list': [('B', 2),
#    ('.', 2),
#    ('giúp', 2),
#    ('đỡ', 2),
#    ('nước', 2),
#    ('Pháp', 2),
#    ('kéo', 2),
#    ('dài', 2),
#    ('cuộc', 2),
#    ('chiến', 2),
#    ('tranh', 2),
#    ('Đông', 2),
#    ('Dương', 2),
#    ('.',
#     2)], 'original_string': 'B. giúp đỡ nước Pháp kéo dài cuộc chiến tranh Đông Dương.'},
#  (115,
#   471,
#   512,
#   493): {'token_list': [('đối', 0),
#    ('ngoại', 0),
#    ('ng', 0),
#    ('ả', 0),
#    ('về', 0),
#    ('phương', 0),
#    ('Tây', 0),
#    ('với', 0),
#    ('hi', 0),
#    ('vọng', 0)], 'original_string': 'đối ngoại ngả về phương Tây với hi vọng'},
#  (160,
#   515,
#   631,
#   536): {'token_list': [('B', 2),
#    ('.', 2),
#    ('xây', 2),
#    ('dựng', 2),
#    ('một', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('lớn', 2),
#    ('ở', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    ('.', 2),
#    ('.',
#     2)], 'original_string': 'B. xây dựng một liên minh kinh tế lớn ở châu Âu.'},
#  (159,
#   537,
#   738,
#   558): {'token_list': [('C', 2),
#    ('.', 2),
#    ('nhận', 2),
#    ('được', 2),
#    ('sự', 2),
#    ('ủng', 2),
#    ('hộ', 2),
#    ('về', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('và', 2),
#    ('sự', 2),
#    ('viện', 2),
#    ('trợ', 2),
#    ('về', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('.', 2),
#    ('C', 2),
#    ('.', 2),
#    ('nhận', 2),
#    ('được', 2),
#    ('sự', 2),
#    ('ủng', 2),
#    ('hộ', 2),
#    ('về', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('và', 2),
#    ('sự', 2),
#    ('viện', 2),
#    ('trợ', 2),
#    ('về', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('.',
#     2)], 'original_string': 'C. nhận được sự ủng hộ về chính trị và sự viện trợ về kinh tế.'},
#  (160,
#   494,
#   609,
#   515): {'token_list': [('A', 2),
#    ('.', 2),
#    ('thành', 2),
#    ('lập', 2),
#    ('một', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('ở', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    ('.', 2),
#    ('A', 2),
#    ('.', 2),
#    ('thành', 2),
#    ('lập', 2),
#    ('một', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('ở', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    ('.',
#     2)], 'original_string': 'A. thành lập một liên minh chính trị ở châu Âu.'},
#  (508,
#   97,
#   908,
#   119): {'token_list': [('Bài', 8),
#    ('thi', 8),
#    (':', 8),
#    ('Khoa', 8),
#    ('học', 8),
#    ('xã', 8),
#    ('hội', 8),
#    (';', 8),
#    ('M', 8),
#    ('ô', 8),
#    ('ôn', 8),
#    (':', 8),
#    ('Lịch', 8),
#    ('sử', 8),
#    ('Bài', 8),
#    ('thi', 8),
#    (':', 8),
#    ('Khoa', 8),
#    ('học', 8),
#    ('xã', 8),
#    ('hội', 8),
#    (';', 8),
#    ('M', 8),
#    ('ô', 8),
#    ('ôn', 8),
#    (':', 8),
#    ('Lịch', 8),
#    ('sử', 8)], 'original_string': 'Bài thi: Khoa học xã hội;Môôn: Lịch sử'},
#  (473,
#   60,
#   941,
#   82): {'token_list': [('KY', 8),
#    ('', 8),
#    ('THI', 8),
#    ('TR', 8),
#    ('UNG', 8),
#    ('HỌC', 8),
#    ('PH', 8),
#    ('Ô', 8),
#    ('THÔNG', 8),
#    ('QUỐC', 8),
#    ('KY', 8),
#    ('', 8),
#    ('THI', 8),
#    ('TR', 8),
#    ('UNG', 8),
#    ('HỌC', 8),
#    ('PH', 8),
#    ('Ô', 8),
#    ('THÔNG', 8),
#    ('QUỐC', 8)], 'original_string': 'KY THI TRUNG HỌC PHÔ THÔNG QUỐC'},
#  (147,
#   60,
#   413,
#   82): {'token_list': [('B', 8),
#    ('Ộ', 8),
#    ('GI', 8),
#    ('À', 8),
#    ('O', 8),
#    ('D', 8),
#    ('Ụ', 8),
#    ('C', 8),
#    ('VÀ', 8),
#    ('Đ', 8),
#    ('ẢO', 8),
#    ('B', 8),
#    ('Ộ', 8),
#    ('GI', 8),
#    ('À', 8),
#    ('O', 8),
#    ('D', 8),
#    ('Ụ', 8),
#    ('C', 8),
#    ('VÀ', 8),
#    ('Đ', 8),
#    ('ẢO', 8)], 'original_string': 'BỘ GIÀO DỤC VÀ ĐẢO'},
#  (159,
#   279,
#   508,
#   300): {'token_list': [('A', 2),
#    ('.', 2),
#    ('Thành', 2),
#    ('lập', 2),
#    ('tổ', 2),
#    ('chức', 2),
#    ('Liên', 2),
#    ('hợp', 2),
#    ('quốc', 2),
#    ('.', 2),
#    ('A', 2),
#    ('.', 2),
#    ('Thành', 2),
#    ('lập', 2),
#    ('tổ', 2),
#    ('chức', 2),
#    ('Liên', 2),
#    ('hợp', 2),
#    ('quốc', 2),
#    ('.', 2)], 'original_string': 'A. Thành lập tổ chức Liên hợp quốc.'},
#  (159,
#   301,
#   532,
#   322): {'token_list': [('B', 2),
#    ('.', 2),
#    ('Giải', 2),
#    ('giáp', 2),
#    ('quân', 2),
#    ('Nhật', 2),
#    ('ở', 2),
#    ('Đông', 2),
#    ('Dương', 2),
#    ('.', 2),
#    ('B', 2),
#    ('.', 2),
#    ('Giải', 2),
#    ('giáp', 2),
#    ('quân', 2),
#    ('Nhật', 2),
#    ('ở', 2),
#    ('Đông', 2),
#    ('Dương', 2),
#    ('.', 2)], 'original_string': 'B. Giải giáp quân Nhật ở Đông Dương.'},
#  (159,
#   322,
#   529,
#   343): {'token_list': [('C', 2),
#    ('.', 2),
#    ('Tiêu', 2),
#    ('diệt', 2),
#    ('tận', 2),
#    ('gốc', 2),
#    ('chủ', 2),
#    ('nghĩa', 2),
#    ('phát', 2),
#    ('x', 2),
#    ('ít', 2),
#    ('.', 2),
#    ('C', 2),
#    ('.', 2),
#    ('Tiêu', 2),
#    ('diệt', 2),
#    ('tận', 2),
#    ('gốc', 2),
#    ('chủ', 2),
#    ('nghĩa', 2),
#    ('phát', 2),
#    ('x', 2),
#    ('ít', 2),
#    ('.', 2)], 'original_string': 'C. Tiêu diệt tận gốc chủ nghĩa phát xít.'},
#  (115,
#   238,
#   251,
#   258): {'token_list': [('Số', 8),
#    ('báo', 8),
#    ('danh', 8),
#    (':', 8),
#    ('Số', 8),
#    ('báo', 8),
#    ('danh', 8),
#    (':', 8)], 'original_string': 'Số báo danh:'},
#  (114,
#   257,
#   794,
#   278): {'token_list': [('Câu', 0),
#    ('1.', 0),
#    ('Hội', 0),
#    ('nghị', 0),
#    ('I', 0),
#    ('anta', 0),
#    ('(2', 0),
#    ('-', 0),
#    ('1945', 0),
#    (')', 0),
#    ('không', 0),
#    ('đưa', 0),
#    ('ra', 0),
#    ('quyết', 0),
#    ('định', 0),
#    ('nào', 0),
#    ('dưới', 0),
#    ('đây', 0),
#    ('?', 0),
#    ('Câu', 0),
#    ('1.', 0),
#    ('Hội', 0),
#    ('nghị', 0),
#    ('I', 0),
#    ('anta', 0),
#    ('(2', 0),
#    ('-', 0),
#    ('1945', 0),
#    (')', 0),
#    ('không', 0),
#    ('đưa', 0),
#    ('ra', 0),
#    ('quyết', 0),
#    ('định', 0),
#    ('nào', 0),
#    ('dưới', 0),
#    ('đây', 0),
#    ('?',
#     0)], 'original_string': 'Câu 1. Hội nghị Ianta (2-1945) không đưa ra quyết định nào dưới đây?'},
#  (114,
#   238,
#   707,
#   258): {'token_list': [('Số', 8),
#    ('báo', 8),
#    ('danh', 8),
#    (':', 8),
#    (':', 8),
#    ('.........', 8),
#    ('Số', 8),
#    ('báo', 8),
#    ('danh', 8),
#    (':', 8),
#    (':', 8),
#    ('.........', 8),
#    ('................', 8),
#    ('................', 8),
#    ('................', 8),
#    ('................',
#     8)], 'original_string': 'Số báo danh:: .........................................................................'},
#  (115,
#   219,
#   305,
#   240): {'token_list': [('Họ', 8),
#    ('và', 8),
#    ('tên', 8),
#    ('thí', 8),
#    ('sinh', 8),
#    (':', 8)], 'original_string': 'Họ và tên thí sinh:'},
#  (159,
#   921,
#   725,
#   943): {'token_list': [('D', 2),
#    ('.', 2),
#    ('tổ', 2),
#    ('chức', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('-', 2),
#    ('qu', 2),
#    ('ân', 2),
#    ('sự', 2),
#    ('chống', 2),
#    ('lại', 2),
#    ('', 2),
#    ('phe', 2),
#    ('xã', 2),
#    ('hội', 2),
#    ('chủ', 2),
#    ('nghĩa', 2),
#    ('.',
#     2)], 'original_string': 'D. tổ chức chính trị-quân sự chống lại phe xã hội chủ nghĩa.'},
#  (160,
#   900,
#   726,
#   921): {'token_list': [('C', 2),
#    ('.', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('chống', 2),
#    ('Liên', 2),
#    ('X', 2),
#    ('ô', 2),
#    ('và', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('Đông', 2),
#    ('Âu', 2),
#    ('.',
#     2)], 'original_string': 'C. liên minh chính trị chống Liên Xô và các nước Đông Âu.'},
#  (160,
#   878,
#   720,
#   899): {'token_list': [('B', 2),
#    ('.', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('quân', 2),
#    ('sự', 2),
#    ('chống', 2),
#    ('Liên', 2),
#    ('X', 2),
#    ('ô', 2),
#    ('và', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('Đông', 2),
#    ('Âu', 2),
#    ('.',
#     2)], 'original_string': 'B. liên minh quân sự chống Liên Xô và các nước Đông Âu.'},
#  (160,
#   857,
#   714,
#   878): {'token_list': [('A', 2),
#    ('.', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('đối', 2),
#    ('lập', 2),
#    ('với', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('xã', 2),
#    ('hội', 2),
#    ('chủ', 2),
#    ('nghĩa', 2),
#    ('.',
#     2)], 'original_string': 'A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.'},
#  (115,
#   838,
#   598,
#   859): {'token_list': [('M', 0),
#    ('ĩ', 0),
#    ('(19', 0),
#    ('47)', 0),
#    ('còn', 0),
#    ('nhằm', 0),
#    ('tập', 0),
#    ('hợp', 0),
#    ('các', 0),
#    ('nước', 0),
#    ('Tây', 0),
#    ('Âu', 0),
#    ('vào',
#     0)], 'original_string': 'Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào'},
#  (160,
#   98,
#   400,
#   121): {'token_list': [('Đ', 8),
#    ('Ề', 8),
#    ('', 8),
#    ('THI', 8),
#    ('TH', 8),
#    ('Ử', 8),
#    ('NG', 8),
#    ('HI', 8),
#    ('Ệ', 8),
#    ('M', 8)], 'original_string': 'ĐỀ THI THỬ NGHIỆM'},
#  (625,
#   78,
#   789,
#   95): {'token_list': [('', 8),
#    ('GIA', 8),
#    ('N', 8),
#    ('Ă', 8),
#    ('M', 8),
#    ('2017', 8)], 'original_string': 'GIA NĂM 2017'},
#  (75,
#   0,
#   266,
#   19): {'token_list': [('VI', 4),
#    ('ET', 4),
#    (',', 4),
#    ('JA', 4),
#    ('CK', 4),
#    ('.', 4),
#    ('COM', 4)], 'original_string': 'VIET,JACK.COM'},
#  (342,
#   0,
#   835,
#   20): {'token_list': [('Học', 4),
#    ('trực', 4),
#    ('tuyến', 4),
#    (':', 4),
#    ('KH', 4),
#    ('OA', 4),
#    ('HỌC', 4),
#    ('.', 4),
#    ('VIE', 4),
#    ('T', 4),
#    ('JA', 4),
#    ('CK', 4),
#    ('.', 4),
#    ('COM', 4)], 'original_string': 'Học trực tuyến: KHOA HỌC.VIETJACK.COM'},
#  (74,
#   949,
#   378,
#   969): {'token_list': [('Facebook', 5),
#    (':', 5),
#    ('Học', 5),
#    ('cùng', 5),
#    ('Viet', 5),
#    ('jack', 5)], 'original_string': 'Facebook: Học cùng Vietjack'},
#  (518,
#   949,
#   805,
#   970): {'token_list': [('Youtube', 5),
#    (':', 5),
#    ('H', 5),
#    ('ọc', 5),
#    ('cùng', 5),
#    ('Viet', 5),
#    ('jack', 5)], 'original_string': 'Youtube:Học cùng Vietjack'}}

# %%
# sample_box = instance_dict.popitem()

# %%
def majority_voting_label(token_list):
    vote_counts = {}
    for token in token_list:
        vote = token[1]
        if vote in vote_counts.keys():
            vote_counts[vote] += 1
        else:
            vote_counts[vote] = 1

    # winners = []
    max_count = max(vote_counts.values())
    for vote, count in vote_counts.items():
        if count == max_count:
            # winners.append(vote)

            return vote

    # if ties, then the result would be random accordingly to the order of vote

# majority_voting_label(sample_box[1])

# %%
for box, box_info in instance_dict.items():
    box_info['box_label'] = majority_voting_label(box_info['token_list'])

# %%
import pickle

with open("example_output_for_an_image.bin", 'wb') as f:
    p = pickle.Pickler(f)
    p.dump(instance_dict)

# %%
instance_dict
# Out:
# {(183,
#   118,
#   377,
#   140): {'token_list': [('(', 8),
#    ('Đ', 8),
#    ('ề', 8),
#    ('thi', 8),
#    ('có', 8),
#    ('05', 8),
#    ('trang', 8),
#    (')', 8)], 'original_string': '(Đề thi có 05 trang)', 'box_label': 8},
#  (159,
#   344,
#   659,
#   365): {'token_list': [('D', 2),
#    ('.', 2),
#    ('Phân', 2),
#    ('chia', 2),
#    ('phạm', 2),
#    ('vi', 2),
#    ('ảnh', 2),
#    ('hưởng', 2),
#    ('ở', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    (',', 2),
#    ('châu', 2),
#    ('Á', 2),
#    ('.',
#     2)], 'original_string': 'D. Phân chia phạm vi ảnh hưởng ở châu Âu, châu Á.', 'box_label': 2},
#  (485,
#   118,
#   931,
#   140): {'token_list': [('Thời', 8),
#    ('gian', 8),
#    ('làm', 8),
#    ('bài', 8),
#    (':', 8),
#    ('50', 8),
#    ('phút', 8),
#    (',', 8),
#    ('không', 8),
#    ('kể', 8),
#    ('thời', 8),
#    ('gian',
#     8)], 'original_string': 'Thời gian làm bài: 50 phút, không kể thời gian', 'box_label': 8},
#  (669, 138, 748, 159): {'token_list': [('phát', 8), ('để', 8)],
#   'original_string': 'phát để',
#   'box_label': 8},
#  (630,
#   180,
#   774,
#   198): {'token_list': [('Mã', 8),
#    ('đề', 8),
#    ('thi', 8),
#    ('(', 8),
#    ('01', 8)], 'original_string': 'Mã đề thi (01', 'box_label': 8},
#  (114,
#   219,
#   730,
#   239): {'token_list': [('Họ', 8),
#    ('và', 8),
#    ('tên', 8),
#    ('thí', 8),
#    ('sinh', 8),
#    (':', 8),
#    ('.......', 8),
#    ('................', 8),
#    ('................', 8),
#    ('................', 8),
#    ('................',
#     8)], 'original_string': 'Họ và tên thí sinh: .......................................................................', 'box_label': 8},
#  (251, 78, 310, 98): {'token_list': [('T', 8), ('Ạ', 8), ('O', 8)],
#   'original_string': 'TẠO',
#   'box_label': 8},
#  (113,
#   365,
#   926,
#   386): {'token_list': [('Câu', 0),
#    ('2.', 0),
#    ('Ngày', 0),
#    ('24', 0),
#    ('-10-', 0),
#    ('1945', 0),
#    (',', 0),
#    ('sau', 0),
#    ('khi', 0),
#    ('Quốc', 0),
#    ('hội', 0),
#    ('các', 0),
#    ('nước', 0),
#    ('thành', 0),
#    ('viên', 0),
#    ('phê', 0),
#    ('chuẩn', 0),
#    (',', 0),
#    ('bản', 0),
#    ('Hi', 0),
#    ('ến',
#     0)], 'original_string': 'Câu 2. Ngày 24-10-1945, sau khi Quốc hội các nước thành viên phê chuẩn, bản Hiến', 'box_label': 0},
#  (115,
#   387,
#   373,
#   408): {'token_list': [('chương', 0),
#    ('của', 0),
#    ('Liên', 0),
#    ('hợp', 0),
#    ('quốc',
#     0)], 'original_string': 'chương của Liên hợp quốc', 'box_label': 0},
#  (160,
#   407,
#   443,
#   428): {'token_list': [('A', 2),
#    ('.', 2),
#    ('được', 2),
#    ('bổ', 2),
#    ('sung', 2),
#    (',', 2),
#    ('hoàn', 2),
#    ('chỉnh', 2),
#    ('.',
#     2)], 'original_string': 'A. được bổ sung, hoàn chỉnh.', 'box_label': 2},
#  (159,
#   428,
#   408,
#   449): {'token_list': [('C', 2),
#    ('.', 2),
#    ('chính', 2),
#    ('thức', 2),
#    ('có', 2),
#    ('hiệu', 2),
#    ('lực', 2),
#    ('.', 2)], 'original_string': 'C. chính thức có hiệu lực.', 'box_label': 2},
#  (160,
#   645,
#   745,
#   666): {'token_list': [('C', 2),
#    (',', 2),
#    ('thực', 2),
#    ('hiện', 2),
#    ('Kế', 2),
#    ('hoạch', 2),
#    ('M', 2),
#    ('ács', 2),
#    ('an', 2),
#    (',', 2),
#    ('giúp', 2),
#    ('Tây', 2),
#    ('Âu', 2),
#    ('phục', 2),
#    ('hồi', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('.',
#     2)], 'original_string': 'C, thực hiện Kế hoạch Mácsan, giúp Tây Âu phục hồi kinh tế.', 'box_label': 2},
#  (537,
#   406,
#   810,
#   429): {'token_list': [('È', 2),
#    (',', 2),
#    ('chính', 2),
#    ('thức', 2),
#    ('được', 2),
#    ('công', 2),
#    ('bố', 2),
#    ('.',
#     2)], 'original_string': 'È, chính thức được công bố.', 'box_label': 2},
#  (160,
#   666,
#   756,
#   687): {'token_list': [('D', 2),
#    ('.', 2),
#    ('viện', 2),
#    ('trợ', 2),
#    ('khẩn', 2),
#    ('cấp', 2),
#    ('400', 2),
#    ('triệu', 2),
#    ('USD', 2),
#    ('cho', 2),
#    ('Hi', 2),
#    ('L', 2),
#    ('ạp', 2),
#    ('và', 2),
#    ('Th', 2),
#    ('ổ', 2),
#    ('Nh', 2),
#    ('ĩ', 2),
#    ('K', 2),
#    ('ì', 2),
#    ('.',
#     2)], 'original_string': 'D. viện trợ khẩn cấp 400 triệu USD cho Hi Lạp và Thổ Nhĩ Kì.', 'box_label': 2},
#  (160,
#   794,
#   862,
#   814): {'token_list': [('D', 2),
#    ('.', 2),
#    ('thúc', 2),
#    ('đẩy', 2),
#    ('tốc', 2),
#    ('độ', 2),
#    ('tăng', 2),
#    ('trưởng', 2),
#    ('của', 2),
#    ('các', 2),
#    ('ngành', 2),
#    ('công', 2),
#    ('nghiệp', 2),
#    ('nhẹ', 2),
#    ('trong', 2),
#    ('nước', 2),
#    ('.',
#     2)], 'original_string': 'D. thúc đẩy tốc độ tăng trưởng của các ngành công nghiệp nhẹ trong nước.', 'box_label': 2},
#  (114,
#   688,
#   932,
#   709): {'token_list': [('Cầu', 2),
#    ('5.', 2),
#    ('Sau', 2),
#    ('khi', 2),
#    ('giành', 2),
#    ('được', 2),
#    ('độc', 2),
#    ('lập', 2),
#    (',', 2),
#    ('nhóm', 2),
#    ('năm', 2),
#    ('nước', 2),
#    ('sáng', 2),
#    ('lập', 2),
#    ('ASEAN', 2),
#    ('thực', 2),
#    ('hiện', 2),
#    ('chiến',
#     2)], 'original_string': 'Cầu 5. Sau khi giành được độc lập, nhóm năm nước sáng lập ASEAN thực hiện chiến', 'box_label': 2},
#  (114,
#   815,
#   926,
#   836): {'token_list': [('Câu', 0),
#    ('6.', 0),
#    ('Ngoài', 0),
#    ('việc', 0),
#    ('giúp', 0),
#    ('các', 0),
#    ('nước', 0),
#    ('Tây', 0),
#    ('Âu', 0),
#    ('phục', 0),
#    ('hồi', 0),
#    ('nền', 0),
#    ('kinh', 0),
#    ('tế', 0),
#    (',', 0),
#    ('Kế', 0),
#    ('hoạch', 0),
#    ('M', 0),
#    ('ács', 0),
#    ('an', 0),
#    ('của',
#     0)], 'original_string': 'Câu 6. Ngoài việc giúp các nước Tây Âu phục hồi nền kinh tế, Kế hoạch Mácsan của', 'box_label': 0},
#  (114,
#   710,
#   459,
#   731): {'token_list': [('T', 2),
#    ('ược', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('hướng', 2),
#    ('nội', 2),
#    ('với', 2),
#    ('mục', 2),
#    ('tiêu',
#     2)], 'original_string': 'Tược kinh tế hướng nội với mục tiêu', 'box_label': 2},
#  (160,
#   773,
#   849,
#   793): {'token_list': [('C', 2),
#    ('.', 2),
#    ('nhanh', 2),
#    ('chóng', 2),
#    ('vươn', 2),
#    ('lên', 2),
#    ('trở', 2),
#    ('thành', 2),
#    ('những', 2),
#    ('nước', 2),
#    ('công', 2),
#    ('nghiệp', 2),
#    ('mới', 2),
#    ('(', 2),
#    ('NIC', 2),
#    ('s', 2),
#    (').',
#     2)], 'original_string': 'C. nhanh chóng vươn lên trở thành những nước công nghiệp mới (NICs).', 'box_label': 2},
#  (160,
#   730,
#   833,
#   750): {'token_list': [('À', 2),
#    ('.', 2),
#    ('khô', 2),
#    ('i', 2),
#    ('phục', 2),
#    ('sự', 2),
#    ('phát', 2),
#    ('triển', 2),
#    ('của', 2),
#    ('các', 2),
#    ('ngành', 2),
#    ('công', 2),
#    ('nghiệp', 2),
#    ('nặng', 2),
#    ('ở', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('.',
#     2)], 'original_string': 'À. khôi phục sự phát triển của các ngành công nghiệp nặng ở các nước.', 'box_label': 2},
#  (160,
#   751,
#   840,
#   771): {'token_list': [('B', 2),
#    ('.', 2),
#    ('nhanh', 2),
#    ('chóng', 2),
#    ('xóa', 2),
#    ('bỏ', 2),
#    ('nghèo', 2),
#    ('n', 2),
#    ('àn', 2),
#    (',', 2),
#    ('lạc', 2),
#    ('hậu', 2),
#    (',', 2),
#    ('xây', 2),
#    ('dựng', 2),
#    ('nền', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('tự', 2),
#    ('chủ', 2),
#    ('.',
#     2)], 'original_string': 'B. nhanh chóng xóa bỏ nghèo nàn, lạc hậu, xây dựng nền kinh tế tự chủ.', 'box_label': 2},
#  (537,
#   428,
#   830,
#   450): {'token_list': [('D', 2),
#    ('.', 2),
#    ('được', 2),
#    ('chính', 2),
#    ('thức', 2),
#    ('thông', 2),
#    ('qua', 2),
#    ('.',
#     2)], 'original_string': 'D. được chính thức thông qua.', 'box_label': 2},
#  (113,
#   449,
#   909,
#   471): {'token_list': [('Câu', 0),
#    ('3.', 0),
#    ('Những', 0),
#    ('năm', 0),
#    ('đầu', 0),
#    ('sau', 0),
#    ('khi', 0),
#    ('Liên', 0),
#    ('X', 0),
#    ('ô', 0),
#    ('tan', 0),
#    ('', 0),
#    ('rã', 0),
#    (',', 0),
#    ('Diện', 0),
#    ('bang', 0),
#    ('Nga', 0),
#    ('thực', 0),
#    ('hiện', 0),
#    ('chính', 0),
#    ('sách',
#     0)], 'original_string': 'Câu 3. Những năm đầu sau khi Liên Xô tan rã, Diện bang Nga thực hiện chính sách', 'box_label': 0},
#  (159,
#   559,
#   759,
#   579): {'token_list': [('D', 2),
#    ('.', 2),
#    ('tăng', 2),
#    ('cường', 2),
#    ('hợp', 2),
#    ('lắc', 2),
#    ('khoa', 2),
#    ('học', 2),
#    ('kĩ', 2),
#    ('thuật', 2),
#    ('với', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    ('.',
#     2)], 'original_string': 'D. tăng cường hợp lắc khoa học kĩ thuật với các nước châu Âu.', 'box_label': 2},
#  (115,
#   580,
#   745,
#   601): {'token_list': [('Câu', 0),
#    ('4.', 0),
#    ('Tại', 0),
#    ('Quốc', 0),
#    ('hội', 0),
#    ('M', 0),
#    ('ĩ', 0),
#    ('(12', 0),
#    ('-3', 0),
#    ('-', 0),
#    ('1947', 0),
#    ('),', 0),
#    ('Tổng', 0),
#    ('thống', 0),
#    ('Tru', 0),
#    ('man', 0),
#    ('đề', 0),
#    ('nghị',
#     0)], 'original_string': 'Câu 4. Tại Quốc hội Mĩ (12-3-1947), Tổng thống Truman đề nghị', 'box_label': 0},
#  (160,
#   602,
#   741,
#   622): {'token_list': [('A', 2),
#    ('.', 2),
#    ('thành', 2),
#    ('lập', 2),
#    ('Tổ', 2),
#    ('chức', 2),
#    ('Hiệp', 2),
#    ('ước', 2),
#    ('Bắc', 2),
#    ('Đại', 2),
#    ('Tây', 2),
#    ('Dương', 2),
#    ('(', 2),
#    ('NATO', 2),
#    (').',
#     2)], 'original_string': 'A. thành lập Tổ chức Hiệp ước Bắc Đại Tây Dương (NATO).', 'box_label': 2},
#  (160,
#   624,
#   736,
#   644): {'token_list': [('B', 2),
#    ('.', 2),
#    ('giúp', 2),
#    ('đỡ', 2),
#    ('nước', 2),
#    ('Pháp', 2),
#    ('kéo', 2),
#    ('dài', 2),
#    ('cuộc', 2),
#    ('chiến', 2),
#    ('tranh', 2),
#    ('Đông', 2),
#    ('Dương', 2),
#    ('.',
#     2)], 'original_string': 'B. giúp đỡ nước Pháp kéo dài cuộc chiến tranh Đông Dương.', 'box_label': 2},
#  (115,
#   471,
#   512,
#   493): {'token_list': [('đối', 0),
#    ('ngoại', 0),
#    ('ng', 0),
#    ('ả', 0),
#    ('về', 0),
#    ('phương', 0),
#    ('Tây', 0),
#    ('với', 0),
#    ('hi', 0),
#    ('vọng',
#     0)], 'original_string': 'đối ngoại ngả về phương Tây với hi vọng', 'box_label': 0},
#  (160,
#   515,
#   631,
#   536): {'token_list': [('B', 2),
#    ('.', 2),
#    ('xây', 2),
#    ('dựng', 2),
#    ('một', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('lớn', 2),
#    ('ở', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    ('.', 2),
#    ('.',
#     2)], 'original_string': 'B. xây dựng một liên minh kinh tế lớn ở châu Âu.', 'box_label': 2},
#  (159,
#   537,
#   738,
#   558): {'token_list': [('C', 2),
#    ('.', 2),
#    ('nhận', 2),
#    ('được', 2),
#    ('sự', 2),
#    ('ủng', 2),
#    ('hộ', 2),
#    ('về', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('và', 2),
#    ('sự', 2),
#    ('viện', 2),
#    ('trợ', 2),
#    ('về', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('.', 2),
#    ('C', 2),
#    ('.', 2),
#    ('nhận', 2),
#    ('được', 2),
#    ('sự', 2),
#    ('ủng', 2),
#    ('hộ', 2),
#    ('về', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('và', 2),
#    ('sự', 2),
#    ('viện', 2),
#    ('trợ', 2),
#    ('về', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('.',
#     2)], 'original_string': 'C. nhận được sự ủng hộ về chính trị và sự viện trợ về kinh tế.', 'box_label': 2},
#  (160,
#   494,
#   609,
#   515): {'token_list': [('A', 2),
#    ('.', 2),
#    ('thành', 2),
#    ('lập', 2),
#    ('một', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('ở', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    ('.', 2),
#    ('A', 2),
#    ('.', 2),
#    ('thành', 2),
#    ('lập', 2),
#    ('một', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('ở', 2),
#    ('châu', 2),
#    ('Âu', 2),
#    ('.',
#     2)], 'original_string': 'A. thành lập một liên minh chính trị ở châu Âu.', 'box_label': 2},
#  (508,
#   97,
#   908,
#   119): {'token_list': [('Bài', 8),
#    ('thi', 8),
#    (':', 8),
#    ('Khoa', 8),
#    ('học', 8),
#    ('xã', 8),
#    ('hội', 8),
#    (';', 8),
#    ('M', 8),
#    ('ô', 8),
#    ('ôn', 8),
#    (':', 8),
#    ('Lịch', 8),
#    ('sử', 8),
#    ('Bài', 8),
#    ('thi', 8),
#    (':', 8),
#    ('Khoa', 8),
#    ('học', 8),
#    ('xã', 8),
#    ('hội', 8),
#    (';', 8),
#    ('M', 8),
#    ('ô', 8),
#    ('ôn', 8),
#    (':', 8),
#    ('Lịch', 8),
#    ('sử',
#     8)], 'original_string': 'Bài thi: Khoa học xã hội;Môôn: Lịch sử', 'box_label': 8},
#  (473,
#   60,
#   941,
#   82): {'token_list': [('KY', 8),
#    ('', 8),
#    ('THI', 8),
#    ('TR', 8),
#    ('UNG', 8),
#    ('HỌC', 8),
#    ('PH', 8),
#    ('Ô', 8),
#    ('THÔNG', 8),
#    ('QUỐC', 8),
#    ('KY', 8),
#    ('', 8),
#    ('THI', 8),
#    ('TR', 8),
#    ('UNG', 8),
#    ('HỌC', 8),
#    ('PH', 8),
#    ('Ô', 8),
#    ('THÔNG', 8),
#    ('QUỐC',
#     8)], 'original_string': 'KY THI TRUNG HỌC PHÔ THÔNG QUỐC', 'box_label': 8},
#  (147,
#   60,
#   413,
#   82): {'token_list': [('B', 8),
#    ('Ộ', 8),
#    ('GI', 8),
#    ('À', 8),
#    ('O', 8),
#    ('D', 8),
#    ('Ụ', 8),
#    ('C', 8),
#    ('VÀ', 8),
#    ('Đ', 8),
#    ('ẢO', 8),
#    ('B', 8),
#    ('Ộ', 8),
#    ('GI', 8),
#    ('À', 8),
#    ('O', 8),
#    ('D', 8),
#    ('Ụ', 8),
#    ('C', 8),
#    ('VÀ', 8),
#    ('Đ', 8),
#    ('ẢO', 8)], 'original_string': 'BỘ GIÀO DỤC VÀ ĐẢO', 'box_label': 8},
#  (159,
#   279,
#   508,
#   300): {'token_list': [('A', 2),
#    ('.', 2),
#    ('Thành', 2),
#    ('lập', 2),
#    ('tổ', 2),
#    ('chức', 2),
#    ('Liên', 2),
#    ('hợp', 2),
#    ('quốc', 2),
#    ('.', 2),
#    ('A', 2),
#    ('.', 2),
#    ('Thành', 2),
#    ('lập', 2),
#    ('tổ', 2),
#    ('chức', 2),
#    ('Liên', 2),
#    ('hợp', 2),
#    ('quốc', 2),
#    ('.',
#     2)], 'original_string': 'A. Thành lập tổ chức Liên hợp quốc.', 'box_label': 2},
#  (159,
#   301,
#   532,
#   322): {'token_list': [('B', 2),
#    ('.', 2),
#    ('Giải', 2),
#    ('giáp', 2),
#    ('quân', 2),
#    ('Nhật', 2),
#    ('ở', 2),
#    ('Đông', 2),
#    ('Dương', 2),
#    ('.', 2),
#    ('B', 2),
#    ('.', 2),
#    ('Giải', 2),
#    ('giáp', 2),
#    ('quân', 2),
#    ('Nhật', 2),
#    ('ở', 2),
#    ('Đông', 2),
#    ('Dương', 2),
#    ('.',
#     2)], 'original_string': 'B. Giải giáp quân Nhật ở Đông Dương.', 'box_label': 2},
#  (159,
#   322,
#   529,
#   343): {'token_list': [('C', 2),
#    ('.', 2),
#    ('Tiêu', 2),
#    ('diệt', 2),
#    ('tận', 2),
#    ('gốc', 2),
#    ('chủ', 2),
#    ('nghĩa', 2),
#    ('phát', 2),
#    ('x', 2),
#    ('ít', 2),
#    ('.', 2),
#    ('C', 2),
#    ('.', 2),
#    ('Tiêu', 2),
#    ('diệt', 2),
#    ('tận', 2),
#    ('gốc', 2),
#    ('chủ', 2),
#    ('nghĩa', 2),
#    ('phát', 2),
#    ('x', 2),
#    ('ít', 2),
#    ('.',
#     2)], 'original_string': 'C. Tiêu diệt tận gốc chủ nghĩa phát xít.', 'box_label': 2},
#  (115,
#   238,
#   251,
#   258): {'token_list': [('Số', 8),
#    ('báo', 8),
#    ('danh', 8),
#    (':', 8),
#    ('Số', 8),
#    ('báo', 8),
#    ('danh', 8),
#    (':', 8)], 'original_string': 'Số báo danh:', 'box_label': 8},
#  (114,
#   257,
#   794,
#   278): {'token_list': [('Câu', 0),
#    ('1.', 0),
#    ('Hội', 0),
#    ('nghị', 0),
#    ('I', 0),
#    ('anta', 0),
#    ('(2', 0),
#    ('-', 0),
#    ('1945', 0),
#    (')', 0),
#    ('không', 0),
#    ('đưa', 0),
#    ('ra', 0),
#    ('quyết', 0),
#    ('định', 0),
#    ('nào', 0),
#    ('dưới', 0),
#    ('đây', 0),
#    ('?', 0),
#    ('Câu', 0),
#    ('1.', 0),
#    ('Hội', 0),
#    ('nghị', 0),
#    ('I', 0),
#    ('anta', 0),
#    ('(2', 0),
#    ('-', 0),
#    ('1945', 0),
#    (')', 0),
#    ('không', 0),
#    ('đưa', 0),
#    ('ra', 0),
#    ('quyết', 0),
#    ('định', 0),
#    ('nào', 0),
#    ('dưới', 0),
#    ('đây', 0),
#    ('?',
#     0)], 'original_string': 'Câu 1. Hội nghị Ianta (2-1945) không đưa ra quyết định nào dưới đây?', 'box_label': 0},
#  (114,
#   238,
#   707,
#   258): {'token_list': [('Số', 8),
#    ('báo', 8),
#    ('danh', 8),
#    (':', 8),
#    (':', 8),
#    ('.........', 8),
#    ('Số', 8),
#    ('báo', 8),
#    ('danh', 8),
#    (':', 8),
#    (':', 8),
#    ('.........', 8),
#    ('................', 8),
#    ('................', 8),
#    ('................', 8),
#    ('................',
#     8)], 'original_string': 'Số báo danh:: .........................................................................', 'box_label': 8},
#  (115,
#   219,
#   305,
#   240): {'token_list': [('Họ', 8),
#    ('và', 8),
#    ('tên', 8),
#    ('thí', 8),
#    ('sinh', 8),
#    (':', 8)], 'original_string': 'Họ và tên thí sinh:', 'box_label': 8},
#  (159,
#   921,
#   725,
#   943): {'token_list': [('D', 2),
#    ('.', 2),
#    ('tổ', 2),
#    ('chức', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('-', 2),
#    ('qu', 2),
#    ('ân', 2),
#    ('sự', 2),
#    ('chống', 2),
#    ('lại', 2),
#    ('', 2),
#    ('phe', 2),
#    ('xã', 2),
#    ('hội', 2),
#    ('chủ', 2),
#    ('nghĩa', 2),
#    ('.',
#     2)], 'original_string': 'D. tổ chức chính trị-quân sự chống lại phe xã hội chủ nghĩa.', 'box_label': 2},
#  (160,
#   900,
#   726,
#   921): {'token_list': [('C', 2),
#    ('.', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('chính', 2),
#    ('trị', 2),
#    ('chống', 2),
#    ('Liên', 2),
#    ('X', 2),
#    ('ô', 2),
#    ('và', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('Đông', 2),
#    ('Âu', 2),
#    ('.',
#     2)], 'original_string': 'C. liên minh chính trị chống Liên Xô và các nước Đông Âu.', 'box_label': 2},
#  (160,
#   878,
#   720,
#   899): {'token_list': [('B', 2),
#    ('.', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('quân', 2),
#    ('sự', 2),
#    ('chống', 2),
#    ('Liên', 2),
#    ('X', 2),
#    ('ô', 2),
#    ('và', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('Đông', 2),
#    ('Âu', 2),
#    ('.',
#     2)], 'original_string': 'B. liên minh quân sự chống Liên Xô và các nước Đông Âu.', 'box_label': 2},
#  (160,
#   857,
#   714,
#   878): {'token_list': [('A', 2),
#    ('.', 2),
#    ('liên', 2),
#    ('minh', 2),
#    ('kinh', 2),
#    ('tế', 2),
#    ('đối', 2),
#    ('lập', 2),
#    ('với', 2),
#    ('các', 2),
#    ('nước', 2),
#    ('xã', 2),
#    ('hội', 2),
#    ('chủ', 2),
#    ('nghĩa', 2),
#    ('.',
#     2)], 'original_string': 'A. liên minh kinh tế đối lập với các nước xã hội chủ nghĩa.', 'box_label': 2},
#  (115,
#   838,
#   598,
#   859): {'token_list': [('M', 0),
#    ('ĩ', 0),
#    ('(19', 0),
#    ('47)', 0),
#    ('còn', 0),
#    ('nhằm', 0),
#    ('tập', 0),
#    ('hợp', 0),
#    ('các', 0),
#    ('nước', 0),
#    ('Tây', 0),
#    ('Âu', 0),
#    ('vào',
#     0)], 'original_string': 'Mĩ (1947) còn nhằm tập hợp các nước Tây Âu vào', 'box_label': 0},
#  (160,
#   98,
#   400,
#   121): {'token_list': [('Đ', 8),
#    ('Ề', 8),
#    ('', 8),
#    ('THI', 8),
#    ('TH', 8),
#    ('Ử', 8),
#    ('NG', 8),
#    ('HI', 8),
#    ('Ệ', 8),
#    ('M', 8)], 'original_string': 'ĐỀ THI THỬ NGHIỆM', 'box_label': 8},
#  (625,
#   78,
#   789,
#   95): {'token_list': [('', 8),
#    ('GIA', 8),
#    ('N', 8),
#    ('Ă', 8),
#    ('M', 8),
#    ('2017', 8)], 'original_string': 'GIA NĂM 2017', 'box_label': 8},
#  (75,
#   0,
#   266,
#   19): {'token_list': [('VI', 4),
#    ('ET', 4),
#    (',', 4),
#    ('JA', 4),
#    ('CK', 4),
#    ('.', 4),
#    ('COM', 4)], 'original_string': 'VIET,JACK.COM', 'box_label': 4},
#  (342,
#   0,
#   835,
#   20): {'token_list': [('Học', 4),
#    ('trực', 4),
#    ('tuyến', 4),
#    (':', 4),
#    ('KH', 4),
#    ('OA', 4),
#    ('HỌC', 4),
#    ('.', 4),
#    ('VIE', 4),
#    ('T', 4),
#    ('JA', 4),
#    ('CK', 4),
#    ('.', 4),
#    ('COM',
#     4)], 'original_string': 'Học trực tuyến: KHOA HỌC.VIETJACK.COM', 'box_label': 4},
#  (74,
#   949,
#   378,
#   969): {'token_list': [('Facebook', 5),
#    (':', 5),
#    ('Học', 5),
#    ('cùng', 5),
#    ('Viet', 5),
#    ('jack',
#     5)], 'original_string': 'Facebook: Học cùng Vietjack', 'box_label': 5},
#  (518,
#   949,
#   805,
#   970): {'token_list': [('Youtube', 5),
#    (':', 5),
#    ('H', 5),
#    ('ọc', 5),
#    ('cùng', 5),
#    ('Viet', 5),
#    ('jack',
#     5)], 'original_string': 'Youtube:Học cùng Vietjack', 'box_label': 5}}

# %%
def containment(box, point):
    if (point[0] > box[0] and point[0] < box[2]) and \
       (point[1] > box[1] and point[1] < box[3]):
        return True

    return False

# %%
def search_box(x, y):
    for box, list_token in instance_dict.items():
        if containment(box, (x,y)):
            return box

# %%
search_box(200,816)
# Out:
# (114, 815, 926, 836)

# %%
def box_divide(box, token_list):
    num_token = len(token_list)
    x0,y0,x1,y1 = box
    sub_boxes = []
    unit = (x1-x0)/num_token
    for i in range(num_token):
        sub_boxes.append((int(x0+i*unit), y0, int(x0+(1+i)*unit), y1))

    return  sub_boxes

box_divide(sample_box[0], sample_box[1])
# Out:
# [(518, 949, 559, 970),
#  (559, 949, 600, 970),
#  (600, 949, 641, 970),
#  (641, 949, 682, 970),
#  (682, 949, 723, 970),
#  (723, 949, 764, 970),
#  (764, 949, 805, 970)]

# %%
# def draw_image_with_component()
import numpy as np
import cv2

image = images
width = image.width
height = image.height


image = np.array(image)
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
for bbox, token_list in instance_dict.items():

    # todo:
    #   xác định major label of each box
    #   parted color field area for each box
    #   return its original

    major_label_id = majority_voting_label(token_list)

    # bbox = boxes[i]
    bbox = unnormalize_bbox(bbox, width, height)
    #
    label = torch_dataset.id2label[major_label_id]
    color = color_map.get(label)[0]
    print(label, color)
    #
    cv2.rectangle(image, (int(bbox[0]), int(bbox[1])),
                  (int(bbox[2]), int(bbox[3])),
                  color, thickness=2)

    label = torch_dataset.id2label[major_label_id]
    cv2.putText(image, label, (int(bbox[0]), int(bbox[1] - 2)), cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=0.25, color=(0, 0, 255), thickness=1)

cv2.imshow("Image with Annotations", image)
cv2.waitKey(0)
# Out:
# starting (211, 63, 69)
# answer (236, 126, 237)
# starting (211, 63, 69)
# starting (211, 63, 69)
# starting (211, 63, 69)
# starting (211, 63, 69)
# starting (211, 63, 69)
# title (148, 102, 168)
# title (148, 102, 168)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# title (148, 102, 168)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# title (148, 102, 168)
# answer (236, 126, 237)
# title (148, 102, 168)
# answer (236, 126, 237)
# answer (236, 126, 237)
# title (148, 102, 168)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# starting (211, 63, 69)
# starting (211, 63, 69)
# starting (211, 63, 69)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# starting (211, 63, 69)
# title (148, 102, 168)
# starting (211, 63, 69)
# answer (236, 126, 237)
# starting (211, 63, 69)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# title (148, 102, 168)
# starting (211, 63, 69)
# starting (211, 63, 69)
# header (124, 125, 121)
# header (124, 125, 121)
# footer (82, 82, 82)
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
#
# QObject::moveToThread: Current thread (0x6efff90) is not the object's thread (0x1b9cca40).
# Cannot move to target thread (0x6efff90)
# 27

# %%
# Out:
# hello black
# hello grey
# hello red
# hello green
# hello yellow
# hello blue
# hello magenta
# hello cyan
# hello light_grey
# hello dark_grey
# hello light_red
# hello light_green
# hello light_yellow
# hello light_blue
# hello light_magenta
# hello light_cyan
# hello white

# %%
from transformers import LayoutXLMProcessor, LayoutLMv2ForTokenClassification
from data_loader_coco_image import DocumentLayoutAnalysisDataset, unnormalize_bbox, color_map
import torch

processor = LayoutXLMProcessor.from_pretrained(
    "microsoft/layoutxlm-base",
    apply_ocr=False,
    only_label_first_subword=False,
    is_split_into_words=True)

anno_file = "/home/tiendq/PycharmProjects/DeepLearningDocReconstruction/0_data_repository/1000DataForOCR_fineLabel_dataset_coco.json"
image_root_folder = "/home/tiendq/Desktop/DocRec/2_data_preparation/2_selected_sample"
torch_dataset = DocumentLayoutAnalysisDataset(image_root_folder, anno_file)

model = LayoutLMv2ForTokenClassification.from_pretrained(
    '/home/tiendq/Desktop/DocRec/3_model_checkpoint/0_model_repository',
    num_labels=len(torch_dataset.label_list),
    id2label=torch_dataset.id2label,
    label2id=torch_dataset.label2id)
# Out:
# /home/tiendq/anaconda3/envs/DeepLearningDocReconstruction/lib/python3.8/site-packages/transformers/models/layoutlmv2/feature_extraction_layoutlmv2.py:30: FutureWarning: The class LayoutLMv2FeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use LayoutLMv2ImageProcessor instead.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.29s)
# creating index...
# index created!

# %%
from PIL import Image

image_column_name = "image"
text_column_name = "words"
boxes_column_name = "boxes"
label_column_name = "labels_id"

examples = torch_dataset[300]

images = Image.open(examples['image_path']).convert("RGB")
words = examples[text_column_name]
boxes = examples[boxes_column_name]
word_labels = examples[label_column_name]

# %%
encoding = processor(images, words, boxes=boxes, word_labels=word_labels, truncation=True, stride =128,
         padding="max_length", max_length=512, return_overflowing_tokens=True, return_offsets_mapping=True, return_tensors='pt')

offset_mapping = encoding.pop('offset_mapping')

overflow_to_sample_mapping = encoding.pop('overflow_to_sample_mapping')

# %%
del encoding['labels']

# %%
# import numpy as np
x = []
for i in range(0, len(encoding['image'])):
     x.append(encoding['image'][i])
x = torch.stack(x)
encoding['image'] = x

# %%
for k,v in encoding.items():
  print(k,type(v), v.shape, sep="\t\t\t\t")
# Out:
# input_ids				<class 'torch.Tensor'>				torch.Size([2, 512])
# attention_mask				<class 'torch.Tensor'>				torch.Size([2, 512])
# bbox				<class 'torch.Tensor'>				torch.Size([2, 512, 4])
# image				<class 'torch.Tensor'>				torch.Size([2, 3, 224, 224])

# %%
with torch.no_grad():
  outputs = model(**encoding)

# The model outputs logits of shape (batch_size, seq_len, num_labels).
logits = outputs.logits
print(logits.shape)

# We take the highest score for each token, using argmax. This serves as the predicted label for each token.
predictions = logits.argmax(-1).squeeze().tolist()
token_boxes = encoding.bbox.squeeze().tolist()

if (len(token_boxes) == 512):
  predictions = [predictions]
  token_boxes = [token_boxes]
# Out:
# torch.Size([2, 512, 9])

# %%
len(token_boxes), token_boxes[0]
# Out:
# (2,
#  [[0, 0, 0, 0],
#   [74, 949, 378, 969],
#   [74, 949, 378, 969],
#   [74, 949, 378, 969],
#   [74, 949, 378, 969],
#   [74, 949, 378, 969],
#   [74, 949, 378, 969],
#   [518, 949, 805, 970],
#   [518, 949, 805, 970],
#   [518, 949, 805, 970],
#   [518, 949, 805, 970],
#   [518, 949, 805, 970],
#   [518, 949, 805, 970],
#   [518, 949, 805, 970],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [342, 0, 835, 20],
#   [75, 0, 266, 19],
#   [75, 0, 266, 19],
#   [75, 0, 266, 19],
#   [75, 0, 266, 19],
#   [75, 0, 266, 19],
#   [75, 0, 266, 19],
#   [75, 0, 266, 19],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [114, 688, 932, 709],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [537, 428, 830, 450],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [159, 428, 408, 449],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 365, 926, 386],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [113, 449, 909, 471],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [159, 279, 508, 300],
#   [630, 180, 774, 198],
#   [630, 180, 774, 198],
#   [630, 180, 774, 198],
#   [630, 180, 774, 198],
#   [630, 180, 774, 198],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [160, 645, 745, 666],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [159, 301, 532, 322],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [160, 751, 840, 771],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [114, 710, 459, 731],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [160, 515, 631, 536],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [114, 219, 730, 239],
#   [625, 78, 789, 95],
#   [625, 78, 789, 95],
#   [625, 78, 789, 95],
#   [625, 78, 789, 95],
#   [625, 78, 789, 95],
#   [625, 78, 789, 95],
#   [115, 387, 373, 408],
#   [115, 387, 373, 408],
#   [115, 387, 373, 408],
#   [115, 387, 373, 408],
#   [115, 387, 373, 408],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 407, 443, 428],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 666, 756, 687],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [160, 900, 726, 921],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [159, 322, 529, 343],
#   [669, 138, 748, 159],
#   [669, 138, 748, 159],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [160, 98, 400, 121],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [159, 559, 759, 579],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [473, 60, 941, 82],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [160, 602, 741, 622],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [114, 238, 707, 258],
#   [115, 219, 305, 240],
#   [115, 219, 305, 240],
#   [115, 219, 305, 240],
#   [115, 219, 305, 240],
#   [115, 219, 305, 240],
#   [115, 219, 305, 240],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [147, 60, 413, 82],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [159, 344, 659, 365],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [115, 471, 512, 493],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [508, 97, 908, 119],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [115, 580, 745, 601],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [183, 118, 377, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [485, 118, 931, 140],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [115, 838, 598, 859],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 773, 849, 793],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [160, 857, 714, 878],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [159, 921, 725, 943],
#   [251, 78, 310, 98],
#   [251, 78, 310, 98],
#   [251, 78, 310, 98],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [160, 794, 862, 814],
#   [1000, 1000, 1000, 1000]])

# %%
for i in range(0, len(token_boxes)):
      for j in range(0, len(token_boxes[i])):
             print("label is: {}, bbox is: {} and the text is: {}".format(torch_dataset.id2label[predictions[i][j]], token_boxes[i][j],  processor.tokenizer.decode(encoding["input_ids"][i][j])))
# Out:
# label is: footer, bbox is: [0, 0, 0, 0] and the text is: <s>
# label is: footer, bbox is: [74, 949, 378, 969] and the text is: Facebook
# label is: footer, bbox is: [74, 949, 378, 969] and the text is: :
# label is: footer, bbox is: [74, 949, 378, 969] and the text is: Học
# label is: footer, bbox is: [74, 949, 378, 969] and the text is: cùng
# label is: footer, bbox is: [74, 949, 378, 969] and the text is: Viet
# label is: footer, bbox is: [74, 949, 378, 969] and the text is: jack
# label is: footer, bbox is: [518, 949, 805, 970] and the text is: Youtube
# label is: footer, bbox is: [518, 949, 805, 970] and the text is: :
# label is: footer, bbox is: [518, 949, 805, 970] and the text is: H
# label is: footer, bbox is: [518, 949, 805, 970] and the text is: ọc
# label is: footer, bbox is: [518, 949, 805, 970] and the text is: cùng
# label is: footer, bbox is: [518, 949, 805, 970] and the text is: Viet
# label is: footer, bbox is: [518, 949, 805, 970] and the text is: jack
# label is: header, bbox is: [342, 0, 835, 20] and the text is: Học
# label is: header, bbox is: [342, 0, 835, 20] and the text is: trực
# label is: header, bbox is: [342, 0, 835, 20] and the text is: tuyến
# label is: header, bbox is: [342, 0, 835, 20] and the text is: :
# label is: header, bbox is: [342, 0, 835, 20] and the text is: KH
# label is: header, bbox is: [342, 0, 835, 20] and the text is: OA
# label is: header, bbox is: [342, 0, 835, 20] and the text is: HỌC
# label is: header, bbox is: [342, 0, 835, 20] and the text is: .
# label is: header, bbox is: [342, 0, 835, 20] and the text is: VIE
# label is: header, bbox is: [342, 0, 835, 20] and the text is: T
# label is: header, bbox is: [342, 0, 835, 20] and the text is: JA
# label is: header, bbox is: [342, 0, 835, 20] and the text is: CK
# label is: header, bbox is: [342, 0, 835, 20] and the text is: .
# label is: header, bbox is: [342, 0, 835, 20] and the text is: COM
# label is: header, bbox is: [75, 0, 266, 19] and the text is: VI
# label is: header, bbox is: [75, 0, 266, 19] and the text is: ET
# label is: header, bbox is: [75, 0, 266, 19] and the text is: ,
# label is: header, bbox is: [75, 0, 266, 19] and the text is: JA
# label is: header, bbox is: [75, 0, 266, 19] and the text is: CK
# label is: header, bbox is: [75, 0, 266, 19] and the text is: .
# label is: header, bbox is: [75, 0, 266, 19] and the text is: COM
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: Cầu
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: 5.
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: Sau
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: khi
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: giành
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: được
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: độc
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: lập
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: ,
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: nhóm
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: năm
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: nước
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: sáng
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: lập
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: ASEAN
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: thực
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: hiện
# label is: answer, bbox is: [114, 688, 932, 709] and the text is: chiến
# label is: answer, bbox is: [537, 428, 830, 450] and the text is: D
# label is: answer, bbox is: [537, 428, 830, 450] and the text is: .
# label is: answer, bbox is: [537, 428, 830, 450] and the text is: được
# label is: answer, bbox is: [537, 428, 830, 450] and the text is: chính
# label is: answer, bbox is: [537, 428, 830, 450] and the text is: thức
# label is: answer, bbox is: [537, 428, 830, 450] and the text is: thông
# label is: answer, bbox is: [537, 428, 830, 450] and the text is: qua
# label is: answer, bbox is: [537, 428, 830, 450] and the text is: .
# label is: answer, bbox is: [159, 428, 408, 449] and the text is: C
# label is: answer, bbox is: [159, 428, 408, 449] and the text is: .
# label is: answer, bbox is: [159, 428, 408, 449] and the text is: chính
# label is: answer, bbox is: [159, 428, 408, 449] and the text is: thức
# label is: answer, bbox is: [159, 428, 408, 449] and the text is: có
# label is: answer, bbox is: [159, 428, 408, 449] and the text is: hiệu
# label is: answer, bbox is: [159, 428, 408, 449] and the text is: lực
# label is: answer, bbox is: [159, 428, 408, 449] and the text is: .
# label is: title, bbox is: [113, 365, 926, 386] and the text is: Câu
# label is: title, bbox is: [113, 365, 926, 386] and the text is: 2.
# label is: title, bbox is: [113, 365, 926, 386] and the text is: Ngày
# label is: title, bbox is: [113, 365, 926, 386] and the text is: 24
# label is: title, bbox is: [113, 365, 926, 386] and the text is: -10-
# label is: title, bbox is: [113, 365, 926, 386] and the text is: 1945
# label is: title, bbox is: [113, 365, 926, 386] and the text is: ,
# label is: title, bbox is: [113, 365, 926, 386] and the text is: sau
# label is: title, bbox is: [113, 365, 926, 386] and the text is: khi
# label is: title, bbox is: [113, 365, 926, 386] and the text is: Quốc
# label is: title, bbox is: [113, 365, 926, 386] and the text is: hội
# label is: title, bbox is: [113, 365, 926, 386] and the text is: các
# label is: title, bbox is: [113, 365, 926, 386] and the text is: nước
# label is: title, bbox is: [113, 365, 926, 386] and the text is: thành
# label is: title, bbox is: [113, 365, 926, 386] and the text is: viên
# label is: title, bbox is: [113, 365, 926, 386] and the text is: phê
# label is: title, bbox is: [113, 365, 926, 386] and the text is: chuẩn
# label is: title, bbox is: [113, 365, 926, 386] and the text is: ,
# label is: title, bbox is: [113, 365, 926, 386] and the text is: bản
# label is: title, bbox is: [113, 365, 926, 386] and the text is: Hi
# label is: title, bbox is: [113, 365, 926, 386] and the text is: ến
# label is: title, bbox is: [113, 449, 909, 471] and the text is: Câu
# label is: title, bbox is: [113, 449, 909, 471] and the text is: 3.
# label is: title, bbox is: [113, 449, 909, 471] and the text is: Những
# label is: title, bbox is: [113, 449, 909, 471] and the text is: năm
# label is: title, bbox is: [113, 449, 909, 471] and the text is: đầu
# label is: title, bbox is: [113, 449, 909, 471] and the text is: sau
# label is: title, bbox is: [113, 449, 909, 471] and the text is: khi
# label is: title, bbox is: [113, 449, 909, 471] and the text is: Liên
# label is: title, bbox is: [113, 449, 909, 471] and the text is: X
# label is: title, bbox is: [113, 449, 909, 471] and the text is: ô
# label is: title, bbox is: [113, 449, 909, 471] and the text is: tan
# label is: title, bbox is: [113, 449, 909, 471] and the text is:
# label is: title, bbox is: [113, 449, 909, 471] and the text is: rã
# label is: title, bbox is: [113, 449, 909, 471] and the text is: ,
# label is: title, bbox is: [113, 449, 909, 471] and the text is: Diện
# label is: title, bbox is: [113, 449, 909, 471] and the text is: bang
# label is: title, bbox is: [113, 449, 909, 471] and the text is: Nga
# label is: title, bbox is: [113, 449, 909, 471] and the text is: thực
# label is: title, bbox is: [113, 449, 909, 471] and the text is: hiện
# label is: title, bbox is: [113, 449, 909, 471] and the text is: chính
# label is: title, bbox is: [113, 449, 909, 471] and the text is: sách
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: A
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: .
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: Thành
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: lập
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: tổ
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: chức
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: Liên
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: hợp
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: quốc
# label is: answer, bbox is: [159, 279, 508, 300] and the text is: .
# label is: starting, bbox is: [630, 180, 774, 198] and the text is: Mã
# label is: starting, bbox is: [630, 180, 774, 198] and the text is: đề
# label is: starting, bbox is: [630, 180, 774, 198] and the text is: thi
# label is: starting, bbox is: [630, 180, 774, 198] and the text is: (
# label is: starting, bbox is: [630, 180, 774, 198] and the text is: 01
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: C
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: ,
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: thực
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: hiện
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: Kế
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: hoạch
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: M
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: ács
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: an
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: ,
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: giúp
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: Tây
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: Âu
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: phục
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: hồi
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: kinh
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: tế
# label is: answer, bbox is: [160, 645, 745, 666] and the text is: .
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: B
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: .
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: Giải
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: giáp
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: quân
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: Nhật
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: ở
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: Đông
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: Dương
# label is: answer, bbox is: [159, 301, 532, 322] and the text is: .
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: B
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: .
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: nhanh
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: chóng
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: xóa
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: bỏ
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: nghèo
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: n
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: àn
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: ,
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: lạc
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: hậu
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: ,
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: xây
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: dựng
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: nền
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: kinh
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: tế
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: tự
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: chủ
# label is: answer, bbox is: [160, 751, 840, 771] and the text is: .
# label is: title, bbox is: [114, 710, 459, 731] and the text is: T
# label is: title, bbox is: [114, 710, 459, 731] and the text is: ược
# label is: title, bbox is: [114, 710, 459, 731] and the text is: kinh
# label is: title, bbox is: [114, 710, 459, 731] and the text is: tế
# label is: title, bbox is: [114, 710, 459, 731] and the text is: hướng
# label is: title, bbox is: [114, 710, 459, 731] and the text is: nội
# label is: title, bbox is: [114, 710, 459, 731] and the text is: với
# label is: title, bbox is: [114, 710, 459, 731] and the text is: mục
# label is: title, bbox is: [114, 710, 459, 731] and the text is: tiêu
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: B
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: .
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: xây
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: dựng
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: một
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: liên
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: minh
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: kinh
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: tế
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: lớn
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: ở
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: châu
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: Âu
# label is: answer, bbox is: [160, 515, 631, 536] and the text is: .
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: Họ
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: và
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: tên
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: thí
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: sinh
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: :
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: .......
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: ................
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: ................
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: ................
# label is: starting, bbox is: [114, 219, 730, 239] and the text is: ................
# label is: starting, bbox is: [625, 78, 789, 95] and the text is:
# label is: starting, bbox is: [625, 78, 789, 95] and the text is: GIA
# label is: starting, bbox is: [625, 78, 789, 95] and the text is: N
# label is: starting, bbox is: [625, 78, 789, 95] and the text is: Ă
# label is: starting, bbox is: [625, 78, 789, 95] and the text is: M
# label is: starting, bbox is: [625, 78, 789, 95] and the text is: 2017
# label is: title, bbox is: [115, 387, 373, 408] and the text is: chương
# label is: title, bbox is: [115, 387, 373, 408] and the text is: của
# label is: title, bbox is: [115, 387, 373, 408] and the text is: Liên
# label is: title, bbox is: [115, 387, 373, 408] and the text is: hợp
# label is: title, bbox is: [115, 387, 373, 408] and the text is: quốc
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: A
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: .
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: được
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: bổ
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: sung
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: ,
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: hoàn
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: chỉnh
# label is: answer, bbox is: [160, 407, 443, 428] and the text is: .
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: D
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: .
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: viện
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: trợ
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: khẩn
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: cấp
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: 400
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: triệu
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: USD
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: cho
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: Hi
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: L
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: ạp
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: và
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: Th
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: ổ
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: Nh
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: ĩ
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: K
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: ì
# label is: answer, bbox is: [160, 666, 756, 687] and the text is: .
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: C
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: .
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: liên
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: minh
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: chính
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: trị
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: chống
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: Liên
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: X
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: ô
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: và
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: các
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: nước
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: Đông
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: Âu
# label is: answer, bbox is: [160, 900, 726, 921] and the text is: .
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: C
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: .
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: Tiêu
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: diệt
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: tận
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: gốc
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: chủ
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: nghĩa
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: phát
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: x
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: ít
# label is: answer, bbox is: [159, 322, 529, 343] and the text is: .
# label is: starting, bbox is: [669, 138, 748, 159] and the text is: phát
# label is: starting, bbox is: [669, 138, 748, 159] and the text is: để
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: Đ
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: Ề
# label is: starting, bbox is: [160, 98, 400, 121] and the text is:
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: THI
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: TH
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: Ử
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: NG
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: HI
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: Ệ
# label is: starting, bbox is: [160, 98, 400, 121] and the text is: M
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: D
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: .
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: tăng
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: cường
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: hợp
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: lắc
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: khoa
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: học
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: kĩ
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: thuật
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: với
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: các
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: nước
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: châu
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: Âu
# label is: answer, bbox is: [159, 559, 759, 579] and the text is: .
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: KY
# label is: starting, bbox is: [473, 60, 941, 82] and the text is:
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: THI
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: TR
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: UNG
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: HỌC
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: PH
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: Ô
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: THÔNG
# label is: starting, bbox is: [473, 60, 941, 82] and the text is: QUỐC
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: A
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: .
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: thành
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: lập
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: Tổ
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: chức
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: Hiệp
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: ước
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: Bắc
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: Đại
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: Tây
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: Dương
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: (
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: NATO
# label is: answer, bbox is: [160, 602, 741, 622] and the text is: ).
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: Số
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: báo
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: danh
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: :
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: :
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: .........
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: ................
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: ................
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: ................
# label is: starting, bbox is: [114, 238, 707, 258] and the text is: ................
# label is: starting, bbox is: [115, 219, 305, 240] and the text is: Họ
# label is: starting, bbox is: [115, 219, 305, 240] and the text is: và
# label is: starting, bbox is: [115, 219, 305, 240] and the text is: tên
# label is: starting, bbox is: [115, 219, 305, 240] and the text is: thí
# label is: starting, bbox is: [115, 219, 305, 240] and the text is: sinh
# label is: starting, bbox is: [115, 219, 305, 240] and the text is: :
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: B
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: Ộ
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: GI
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: À
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: O
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: D
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: Ụ
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: C
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: VÀ
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: Đ
# label is: starting, bbox is: [147, 60, 413, 82] and the text is: ẢO
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: D
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: .
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: Phân
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: chia
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: phạm
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: vi
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: ảnh
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: hưởng
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: ở
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: châu
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: Âu
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: ,
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: châu
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: Á
# label is: answer, bbox is: [159, 344, 659, 365] and the text is: .
# label is: title, bbox is: [115, 471, 512, 493] and the text is: đối
# label is: title, bbox is: [115, 471, 512, 493] and the text is: ngoại
# label is: title, bbox is: [115, 471, 512, 493] and the text is: ng
# label is: title, bbox is: [115, 471, 512, 493] and the text is: ả
# label is: title, bbox is: [115, 471, 512, 493] and the text is: về
# label is: title, bbox is: [115, 471, 512, 493] and the text is: phương
# label is: title, bbox is: [115, 471, 512, 493] and the text is: Tây
# label is: title, bbox is: [115, 471, 512, 493] and the text is: với
# label is: title, bbox is: [115, 471, 512, 493] and the text is: hi
# label is: title, bbox is: [115, 471, 512, 493] and the text is: vọng
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: Bài
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: thi
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: :
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: Khoa
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: học
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: xã
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: hội
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: ;
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: M
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: ô
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: ôn
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: :
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: Lịch
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: sử
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Câu
# label is: title, bbox is: [115, 580, 745, 601] and the text is: 4.
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Tại
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Quốc
# label is: title, bbox is: [115, 580, 745, 601] and the text is: hội
# label is: title, bbox is: [115, 580, 745, 601] and the text is: M
# label is: title, bbox is: [115, 580, 745, 601] and the text is: ĩ
# label is: title, bbox is: [115, 580, 745, 601] and the text is: (12
# label is: title, bbox is: [115, 580, 745, 601] and the text is: -3
# label is: title, bbox is: [115, 580, 745, 601] and the text is: -
# label is: title, bbox is: [115, 580, 745, 601] and the text is: 1947
# label is: title, bbox is: [115, 580, 745, 601] and the text is: ),
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Tổng
# label is: title, bbox is: [115, 580, 745, 601] and the text is: thống
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Tru
# label is: title, bbox is: [115, 580, 745, 601] and the text is: man
# label is: title, bbox is: [115, 580, 745, 601] and the text is: đề
# label is: title, bbox is: [115, 580, 745, 601] and the text is: nghị
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: (
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: Đ
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: ề
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: thi
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: có
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: 05
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: trang
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: )
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: Thời
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: gian
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: làm
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: bài
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: :
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: 50
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: phút
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: ,
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: không
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: kể
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: thời
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: gian
# label is: title, bbox is: [115, 838, 598, 859] and the text is: M
# label is: title, bbox is: [115, 838, 598, 859] and the text is: ĩ
# label is: title, bbox is: [115, 838, 598, 859] and the text is: (19
# label is: title, bbox is: [115, 838, 598, 859] and the text is: 47)
# label is: title, bbox is: [115, 838, 598, 859] and the text is: còn
# label is: title, bbox is: [115, 838, 598, 859] and the text is: nhằm
# label is: title, bbox is: [115, 838, 598, 859] and the text is: tập
# label is: title, bbox is: [115, 838, 598, 859] and the text is: hợp
# label is: title, bbox is: [115, 838, 598, 859] and the text is: các
# label is: title, bbox is: [115, 838, 598, 859] and the text is: nước
# label is: title, bbox is: [115, 838, 598, 859] and the text is: Tây
# label is: title, bbox is: [115, 838, 598, 859] and the text is: Âu
# label is: title, bbox is: [115, 838, 598, 859] and the text is: vào
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: C
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: .
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: nhanh
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: chóng
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: vươn
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: lên
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: trở
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: thành
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: những
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: nước
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: công
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: nghiệp
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: mới
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: (
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: NIC
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: s
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: ).
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: A
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: .
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: liên
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: minh
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: kinh
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: tế
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: đối
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: lập
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: với
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: các
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: nước
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: xã
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: hội
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: chủ
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: nghĩa
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: .
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: D
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: .
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: tổ
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: chức
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: chính
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: trị
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: -
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: qu
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: ân
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: sự
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: chống
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: lại
# label is: answer, bbox is: [159, 921, 725, 943] and the text is:
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: phe
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: xã
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: hội
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: chủ
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: nghĩa
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: .
# label is: starting, bbox is: [251, 78, 310, 98] and the text is: T
# label is: starting, bbox is: [251, 78, 310, 98] and the text is: Ạ
# label is: starting, bbox is: [251, 78, 310, 98] and the text is: O
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: D
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: .
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: thúc
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: đẩy
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: tốc
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: độ
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: tăng
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: trưởng
# label is: answer, bbox is: [1000, 1000, 1000, 1000] and the text is: </s>
# label is: starting, bbox is: [0, 0, 0, 0] and the text is: <s>
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: Bài
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: thi
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: :
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: Khoa
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: học
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: xã
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: hội
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: ;
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: M
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: ô
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: ôn
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: :
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: Lịch
# label is: starting, bbox is: [508, 97, 908, 119] and the text is: sử
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Câu
# label is: title, bbox is: [115, 580, 745, 601] and the text is: 4.
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Tại
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Quốc
# label is: title, bbox is: [115, 580, 745, 601] and the text is: hội
# label is: title, bbox is: [115, 580, 745, 601] and the text is: M
# label is: title, bbox is: [115, 580, 745, 601] and the text is: ĩ
# label is: title, bbox is: [115, 580, 745, 601] and the text is: (12
# label is: title, bbox is: [115, 580, 745, 601] and the text is: -3
# label is: title, bbox is: [115, 580, 745, 601] and the text is: -
# label is: title, bbox is: [115, 580, 745, 601] and the text is: 1947
# label is: title, bbox is: [115, 580, 745, 601] and the text is: ),
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Tổng
# label is: title, bbox is: [115, 580, 745, 601] and the text is: thống
# label is: title, bbox is: [115, 580, 745, 601] and the text is: Tru
# label is: title, bbox is: [115, 580, 745, 601] and the text is: man
# label is: title, bbox is: [115, 580, 745, 601] and the text is: đề
# label is: title, bbox is: [115, 580, 745, 601] and the text is: nghị
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: (
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: Đ
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: ề
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: thi
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: có
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: 05
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: trang
# label is: starting, bbox is: [183, 118, 377, 140] and the text is: )
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: Thời
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: gian
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: làm
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: bài
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: :
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: 50
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: phút
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: ,
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: không
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: kể
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: thời
# label is: starting, bbox is: [485, 118, 931, 140] and the text is: gian
# label is: title, bbox is: [115, 838, 598, 859] and the text is: M
# label is: title, bbox is: [115, 838, 598, 859] and the text is: ĩ
# label is: title, bbox is: [115, 838, 598, 859] and the text is: (19
# label is: title, bbox is: [115, 838, 598, 859] and the text is: 47)
# label is: title, bbox is: [115, 838, 598, 859] and the text is: còn
# label is: title, bbox is: [115, 838, 598, 859] and the text is: nhằm
# label is: title, bbox is: [115, 838, 598, 859] and the text is: tập
# label is: title, bbox is: [115, 838, 598, 859] and the text is: hợp
# label is: title, bbox is: [115, 838, 598, 859] and the text is: các
# label is: title, bbox is: [115, 838, 598, 859] and the text is: nước
# label is: title, bbox is: [115, 838, 598, 859] and the text is: Tây
# label is: title, bbox is: [115, 838, 598, 859] and the text is: Âu
# label is: title, bbox is: [115, 838, 598, 859] and the text is: vào
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: C
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: .
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: nhanh
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: chóng
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: vươn
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: lên
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: trở
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: thành
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: những
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: nước
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: công
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: nghiệp
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: mới
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: (
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: NIC
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: s
# label is: answer, bbox is: [160, 773, 849, 793] and the text is: ).
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: A
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: .
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: liên
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: minh
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: kinh
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: tế
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: đối
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: lập
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: với
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: các
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: nước
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: xã
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: hội
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: chủ
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: nghĩa
# label is: answer, bbox is: [160, 857, 714, 878] and the text is: .
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: D
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: .
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: tổ
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: chức
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: chính
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: trị
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: -
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: qu
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: ân
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: sự
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: chống
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: lại
# label is: answer, bbox is: [159, 921, 725, 943] and the text is:
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: phe
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: xã
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: hội
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: chủ
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: nghĩa
# label is: answer, bbox is: [159, 921, 725, 943] and the text is: .
# label is: starting, bbox is: [251, 78, 310, 98] and the text is: T
# label is: starting, bbox is: [251, 78, 310, 98] and the text is: Ạ
# label is: starting, bbox is: [251, 78, 310, 98] and the text is: O
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: D
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: .
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: thúc
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: đẩy
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: tốc
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: độ
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: tăng
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: trưởng
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: của
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: các
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: ngành
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: công
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: nghiệp
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: nhẹ
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: trong
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: nước
# label is: answer, bbox is: [160, 794, 862, 814] and the text is: .
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: B
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: .
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: giúp
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: đỡ
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: nước
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: Pháp
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: kéo
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: dài
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: cuộc
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: chiến
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: tranh
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: Đông
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: Dương
# label is: answer, bbox is: [160, 624, 736, 644] and the text is: .
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: B
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: .
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: liên
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: minh
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: quân
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: sự
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: chống
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: Liên
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: X
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: ô
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: và
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: các
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: nước
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: Đông
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: Âu
# label is: answer, bbox is: [160, 878, 720, 899] and the text is: .
# label is: title, bbox is: [114, 257, 794, 278] and the text is: Câu
# label is: title, bbox is: [114, 257, 794, 278] and the text is: 1.
# label is: title, bbox is: [114, 257, 794, 278] and the text is: Hội
# label is: title, bbox is: [114, 257, 794, 278] and the text is: nghị
# label is: title, bbox is: [114, 257, 794, 278] and the text is: I
# label is: title, bbox is: [114, 257, 794, 278] and the text is: anta
# label is: title, bbox is: [114, 257, 794, 278] and the text is: (2
# label is: title, bbox is: [114, 257, 794, 278] and the text is: -
# label is: title, bbox is: [114, 257, 794, 278] and the text is: 1945
# label is: title, bbox is: [114, 257, 794, 278] and the text is: )
# label is: title, bbox is: [114, 257, 794, 278] and the text is: không
# label is: title, bbox is: [114, 257, 794, 278] and the text is: đưa
# label is: title, bbox is: [114, 257, 794, 278] and the text is: ra
# label is: title, bbox is: [114, 257, 794, 278] and the text is: quyết
# label is: title, bbox is: [114, 257, 794, 278] and the text is: định
# label is: title, bbox is: [114, 257, 794, 278] and the text is: nào
# label is: title, bbox is: [114, 257, 794, 278] and the text is: dưới
# ...
# label is: title, bbox is: [114, 815, 926, 836] and the text is: Âu
# label is: title, bbox is: [114, 815, 926, 836] and the text is: phục
# label is: title, bbox is: [114, 815, 926, 836] and the text is: hồi
# label is: title, bbox is: [114, 815, 926, 836] and the text is: nền
# label is: title, bbox is: [114, 815, 926, 836] and the text is: kinh
# label is: title, bbox is: [114, 815, 926, 836] and the text is: tế
# label is: title, bbox is: [114, 815, 926, 836] and the text is: ,
# label is: title, bbox is: [114, 815, 926, 836] and the text is: Kế
# label is: title, bbox is: [114, 815, 926, 836] and the text is: hoạch
# label is: title, bbox is: [114, 815, 926, 836] and the text is: M
# label is: title, bbox is: [114, 815, 926, 836] and the text is: ács
# label is: title, bbox is: [114, 815, 926, 836] and the text is: an
# label is: title, bbox is: [114, 815, 926, 836] and the text is: của
# label is: answer, bbox is: [1000, 1000, 1000, 1000] and the text is: </s>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: answer, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>
# label is: title, bbox is: [0, 0, 0, 0] and the text is: <pad>

# %%
instance_dict = {}

for i in range(0, len(token_boxes)):
    for j in range(0, len(token_boxes[i])):
        box = tuple(token_boxes[i][j])
        if box == (0,0,0,0):
            continue
        if box not in instance_dict:
            instance_dict[box] = [(encoding["input_ids"][i][j],predictions[i][j])]
        else:
            instance_dict[box].append((encoding["input_ids"][i][j],predictions[i][j]))

# %%
sample_box = instance_dict.popitem()

# %%
sample_box
# Out:
# ((114, 815, 926, 836),
#  [(tensor(81000), 0),
#   (tensor(2289), 0),
#   (tensor(46158), 0),
#   (tensor(2735), 0),
#   (tensor(8061), 0),
#   (tensor(925), 0),
#   (tensor(3042), 0),
#   (tensor(37409), 0),
#   (tensor(80570), 0),
#   (tensor(15195), 0),
#   (tensor(28588), 0),
#   (tensor(44565), 0),
#   (tensor(5890), 0),
#   (tensor(5893), 0),
#   (tensor(4), 0),
#   (tensor(100801), 0),
#   (tensor(27517), 0),
#   (tensor(276), 0),
#   (tensor(71479), 0),
#   (tensor(66), 0),
#   (tensor(550), 0)])

# %%
def containment(box, point):
    if (point[0] > box[0] and point[0] < box[2]) and \
       (point[1] > box[1] and point[1] < box[3]):
        return True

    return False

# %%
def search_box(x, y):
    for box, list_token in instance_dict.items():
        if containment(box, (x,y)):
            return box

# %%
search_box(200,816)
# Out:
# (114, 815, 926, 836)

# %%
def majority_voting_label(token_list):
    # def majority_vote(l):
    vote_counts = {}
    for token in token_list:
        vote = token[1]
        if vote in vote_counts.keys():
            vote_counts[vote] += 1
        else:
            vote_counts[vote] = 1

    # winners = []
    max_count = max(vote_counts.values())
    for vote, count in vote_counts.items():
        if count == max_count:
            # winners.append(vote)

            return vote

    # if ties, then the result would be random accordingly to the order of vote

majority_voting_label(sample_box[1])
# Out:
# 0

# %%
def box_divide(box, token_list):
    num_token = len(token_list)
    x0,y0,x1,y1 = box
    sub_boxes = []
    unit = (x1-x0)/num_token
    for i in range(num_token):
        sub_boxes.append((int(x0+i*unit), y0, int(x0+(1+i)*unit), y1))

    return  sub_boxes

box_divide(sample_box[0], sample_box[1])
# Out:
# [(114, 815, 152, 836),
#  (152, 815, 191, 836),
#  (191, 815, 230, 836),
#  (230, 815, 268, 836),
#  (268, 815, 307, 836),
#  (307, 815, 346, 836),
#  (346, 815, 384, 836),
#  (384, 815, 423, 836),
#  (423, 815, 462, 836),
#  (462, 815, 500, 836),
#  (500, 815, 539, 836),
#  (539, 815, 578, 836),
#  (578, 815, 616, 836),
#  (616, 815, 655, 836),
#  (655, 815, 694, 836),
#  (694, 815, 732, 836),
#  (732, 815, 771, 836),
#  (771, 815, 810, 836),
#  (810, 815, 848, 836),
#  (848, 815, 887, 836),
#  (887, 815, 926, 836)]

# %%
# def draw_image_with_component()
import numpy as np
import cv2

image = images
width = image.width
height = image.height


image = np.array(image)
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
for bbox, token_list in instance_dict.items():

    # todo:
    #   xác định major label of each box
    #   parted color field area for each box
    #   return its original

    major_label_id = majority_voting_label(token_list)

    # bbox = boxes[i]
    bbox = unnormalize_bbox(bbox, width, height)
    #
    label = torch_dataset.id2label[major_label_id]
    color = color_map.get(label)[0]
    print(label, color)
    #
    cv2.rectangle(image, (int(bbox[0]), int(bbox[1])),
                  (int(bbox[2]), int(bbox[3])),
                  color, thickness=2)

    label = torch_dataset.id2label[major_label_id]
    cv2.putText(image, label, (int(bbox[0]), int(bbox[1] - 2)), cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=0.25, color=(0, 0, 255), thickness=1)

cv2.imshow("Image with Annotations", image)
cv2.waitKey(0)
# Out:
# footer (82, 82, 82)
# footer (82, 82, 82)
# header (124, 125, 121)
# header (124, 125, 121)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# title (148, 102, 168)
# title (148, 102, 168)
# answer (236, 126, 237)
# starting (211, 63, 69)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# title (148, 102, 168)
# answer (236, 126, 237)
# starting (211, 63, 69)
# starting (211, 63, 69)
# title (148, 102, 168)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# starting (211, 63, 69)
# starting (211, 63, 69)
# answer (236, 126, 237)
# starting (211, 63, 69)
# answer (236, 126, 237)
# starting (211, 63, 69)
# starting (211, 63, 69)
# starting (211, 63, 69)
# answer (236, 126, 237)
# title (148, 102, 168)
# starting (211, 63, 69)
# title (148, 102, 168)
# starting (211, 63, 69)
# starting (211, 63, 69)
# title (148, 102, 168)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# starting (211, 63, 69)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# title (148, 102, 168)
# starting (211, 63, 69)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# answer (236, 126, 237)
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)
#
# QObject::moveToThread: Current thread (0x2244b4a0) is not the object's thread (0x36825340).
# Cannot move to target thread (0x2244b4a0)

# %%
from termcolor import colored
import termcolor

for color in  termcolor.COLORS:
    print(colored('hello', color), color)
